# %% [markdown]
# ## Part 3 - Handling with Outliers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import warnings
warnings.filterwarnings("ignore")

# %%
df_origin = pd.read_csv("auto_scout_filled.csv")

# %%
df = df_origin.copy()

# %%
df.head()
# Out:
#   make_model body_type  price(€)               vat       km  hp(kw)  type  \
# 0    Audi A1    Sedans     15770    VAT deductible  56013.0    66.0  Used
# 1    Audi A1    Sedans     14500  Price negotiable  80000.0   141.0  Used
# 2    Audi A1    Sedans     14640    VAT deductible  83450.0    85.0  Used
# 3    Audi A1    Sedans     14500    VAT deductible  73000.0    66.0  Used
# 4    Audi A1    Sedans     16790    VAT deductible  16200.0    66.0  Used
#
#    previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 0              2.0            Yes   Metallic          5.0          5.0
# 1              1.0             No   Metallic          3.0          4.0
# 2              1.0             No   Metallic          4.0          4.0
# 3              1.0             No   Metallic          3.0          4.0
# 4              1.0            Yes   Metallic          5.0          5.0
#
#   gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain     fuel  \
# 0    Automatic            1422.0        3.0      1220.0       front   Diesel
# 1    Automatic            1798.0        4.0      1255.0       front  Benzine
# 2    Automatic            1598.0        3.0      1255.0       front   Diesel
# 3    Automatic            1422.0        3.0      1195.0       front   Diesel
# 4    Automatic            1422.0        3.0      1195.0       front   Diesel
#
#    co2_emission(g/km) emission_class  \
# 0                99.0         Euro 6
# 1               129.0         Euro 6
# 2                99.0         Euro 6
# 3                99.0         Euro 6
# 4               109.0         Euro 6
#
#                              comfort_and_convenience  \
# 0  Air conditioning,Armrest,Automatic climate con...
# 1  Air conditioning,Automatic climate control,Hil...
# 2  Air conditioning,Cruise control,Electrical sid...
# 3  Air suspension,Armrest,Auxiliary heating,Elect...
# 4  Air conditioning,Armrest,Automatic climate con...
#
#                             entertaintment_and_media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                  safety_and_security  gears  age  \
# 0  ABS,Central door lock,Daytime running lights,D...    7.0  3.0
# 1  ABS,Central door lock,Central door lock with r...    7.0  2.0
# 2  ABS,Central door lock,Daytime running lights,D...    7.0  3.0
# 3  ABS,Alarm system,Central door lock with remote...    6.0  3.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...    6.0  3.0
#
#   upholstery_style upholstery_color  consumption_comb(100km/l)
# 0            Cloth            Black                        3.8
# 1            Cloth             Grey                        5.6
# 2            Cloth            Black                        3.8
# 3            Cloth            Black                        3.8
# 4            Cloth            Black                        4.1

# %%
df.describe(include="all").T
# Out:
#                              count unique  \
# make_model                   15919      9
# body_type                    15919      9
# price(€)                   15919.0    NaN
# vat                          15919      2
# km                         15919.0    NaN
# hp(kw)                     15919.0    NaN
# type                         15919      5
# previous_owners            15919.0    NaN
# inspection_new               15919      2
# paint_type                   15919      3
# num_of_door                15919.0    NaN
# num_of_seat                15919.0    NaN
# gearing_type                 15919      3
# displacement(cc)           15919.0    NaN
# cylinders                  15919.0    NaN
# weight(kg)                 15919.0    NaN
# drive_chain                  15919      3
# fuel                         15919      4
# co2_emission(g/km)         15919.0    NaN
# emission_class               15919      3
# comfort_and_convenience      15919   6198
# entertaintment_and_media     15919    346
# extras                       15919    659
# safety_and_security          15919   4443
# gears                      15919.0    NaN
# age                        15919.0    NaN
# upholstery_style             15919      6
# upholstery_color             15919     10
# consumption_comb(100km/l)  15919.0    NaN
#
#                                                                          top  \
# make_model                                                           Audi A3
# body_type                                                             Sedans
# price(€)                                                                 NaN
# vat                                                           VAT deductible
# km                                                                       NaN
# hp(kw)                                                                   NaN
# type                                                                    Used
# previous_owners                                                          NaN
# inspection_new                                                            No
# paint_type                                                          Metallic
# num_of_door                                                              NaN
# num_of_seat                                                              NaN
# gearing_type                                                          Manual
# displacement(cc)                                                         NaN
# cylinders                                                                NaN
# weight(kg)                                                               NaN
# drive_chain                                                            front
# fuel                                                                 Benzine
# co2_emission(g/km)                                                       NaN
# emission_class                                                        Euro 6
# comfort_and_convenience    Air conditioning,Electrical side mirrors,Hill ...
# entertaintment_and_media   Bluetooth,Hands-free equipment,On-board comput...
# extras                                                          Alloy wheels
# safety_and_security        ABS,Central door lock,Daytime running lights,D...
# gears                                                                    NaN
# age                                                                      NaN
# upholstery_style                                                       Cloth
# upholstery_color                                                       Black
# consumption_comb(100km/l)                                                NaN
#
#                             freq          mean          std   min      25%  \
# make_model                  3097           NaN          NaN   NaN      NaN
# body_type                   7925           NaN          NaN   NaN      NaN
# price(€)                     NaN  18019.896727  7386.169409  13.0  12850.0
# vat                        14972           NaN          NaN   NaN      NaN
# km                           NaN  36916.225547   37661.7388   0.0   6437.0
# hp(kw)                       NaN     88.372385    26.840256   1.0     66.0
# type                       11098           NaN          NaN   NaN      NaN
# previous_owners              NaN      1.058169     0.314867   0.0      1.0
# inspection_new             11987           NaN          NaN   NaN      NaN
# paint_type                 15255           NaN          NaN   NaN      NaN
# num_of_door                  NaN      4.655129      0.64706   1.0      4.0
# num_of_seat                  NaN      4.951693     0.499896   2.0      5.0
# gearing_type                8153           NaN          NaN   NaN      NaN
# displacement(cc)             NaN   1424.379735   331.468352   1.0   1229.0
# cylinders                    NaN      3.782775     0.423048   1.0      4.0
# weight(kg)                   NaN    1355.86758   220.520584   1.0   1178.0
# drive_chain                15575           NaN          NaN   NaN      NaN
# fuel                        8551           NaN          NaN   NaN      NaN
# co2_emission(g/km)           NaN     122.17187   248.490428   0.0    106.0
# emission_class             15773           NaN          NaN   NaN      NaN
# comfort_and_convenience      315           NaN          NaN   NaN      NaN
# entertaintment_and_media    1641           NaN          NaN   NaN      NaN
# extras                      5884           NaN          NaN   NaN      NaN
# safety_and_security          729           NaN          NaN   NaN      NaN
# gears                        NaN      5.941831      0.81133   1.0      5.0
# age                          NaN       1.38765     1.121661   0.0      0.0
# upholstery_style           11719           NaN          NaN   NaN      NaN
# upholstery_color           11866           NaN          NaN   NaN      NaN
# consumption_comb(100km/l)    NaN      4.871861     1.556083   0.0      4.0
#
#                                50%      75%       max
# make_model                     NaN      NaN       NaN
# body_type                      NaN      NaN       NaN
# price(€)                   16900.0  21900.0   74600.0
# vat                            NaN      NaN       NaN
# km                         24764.0  61119.0  317000.0
# hp(kw)                        85.0    101.0     294.0
# type                           NaN      NaN       NaN
# previous_owners                1.0      1.0       4.0
# inspection_new                 NaN      NaN       NaN
# paint_type                     NaN      NaN       NaN
# num_of_door                    5.0      5.0       7.0
# num_of_seat                    5.0      5.0       7.0
# gearing_type                   NaN      NaN       NaN
# displacement(cc)            1461.0   1598.0   16000.0
# cylinders                      4.0      4.0       8.0
# weight(kg)                  1305.0   1487.0    2471.0
# drive_chain                    NaN      NaN       NaN
# fuel                           NaN      NaN       NaN
# co2_emission(g/km)           116.0    127.0   14457.0
# emission_class                 NaN      NaN       NaN
# comfort_and_convenience        NaN      NaN       NaN
# entertaintment_and_media       NaN      NaN       NaN
# extras                         NaN      NaN       NaN
# safety_and_security            NaN      NaN       NaN
# gears                          6.0      6.0      50.0
# age                            1.0      2.0       3.0
# upholstery_style               NaN      NaN       NaN
# upholstery_color               NaN      NaN       NaN
# consumption_comb(100km/l)      4.8      5.4      55.0

# %%
df.select_dtypes([np.number]).columns
# Out:
# Index(['price(€)', 'km', 'hp(kw)', 'previous_owners', 'num_of_door',
#        'num_of_seat', 'displacement(cc)', 'cylinders', 'weight(kg)',
#        'co2_emission(g/km)', 'gears', 'age', 'consumption_comb(100km/l)'],
#       dtype='object')

# %% [markdown]
# ### 1- price(€) column

# %%
df["price(€)"].describe()
# Out:
# count    15919.000000
# mean     18019.896727
# std       7386.169409
# min         13.000000
# 25%      12850.000000
# 50%      16900.000000
# 75%      21900.000000
# max      74600.000000
# Name: price(€), dtype: float64

# %%
sns.boxplot(data=df, x="make_model", y="price(€)")
plt.xticks(rotation=90);

# %% [markdown]
# ##### Audi A3

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Audi A3"]["price(€)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (31900.0, 9500.0)

# %%
df[df["make_model"] == "Audi A3"][(df["price(€)"] > upper_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
#      make_model body_type  price(€)             vat       km  hp(kw)  type  \
# 3648    Audi A3    Sedans     74600  VAT deductible  13000.0   294.0  Used
# 3649    Audi A3   Compact     67600  VAT deductible  37747.0   294.0  Used
# 3587    Audi A3    Sedans     64900  VAT deductible  35000.0   294.0  Used
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 3648              1.0             No   Metallic          4.0          5.0
# 3649              1.0             No   Metallic          5.0          5.0
# 3587              1.0             No   Metallic          5.0          5.0
#
#         gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 3648  Semi-automatic            2480.0        5.0      1490.0         4WD
# 3649  Semi-automatic            2480.0        5.0      1485.0         4WD
# 3587  Semi-automatic            2480.0        5.0      1585.0       front
#
#          fuel  co2_emission(g/km) emission_class  \
# 3648  Benzine               188.0         Euro 6
# 3649  Benzine               189.0         Euro 6
# 3587  Benzine               189.0         Euro 6
#
#                                 comfort_and_convenience  \
# 3648  Air conditioning,Armrest,Automatic climate con...
# 3649  Air conditioning,Armrest,Automatic climate con...
# 3587  Air conditioning,Seat ventilation,Split rear s...
#
#                entertaintment_and_media  \
# 3648  CD player,On-board computer,Radio
# 3649  CD player,On-board computer,Radio
# 3587                              Radio
#
#                                                  extras  \
# 3648          Alloy wheels,Sport seats,Sport suspension
# 3649  Alloy wheels,Roof rack,Sport seats,Sport suspe...
# 3587                                       Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 3648  ABS,Alarm system,Central door lock,Driver-side...    7.0  1.0
# 3649  ABS,Alarm system,Central door lock,Driver-side...    7.0  2.0
# 3587  Adaptive Cruise Control,Alarm system,Central d...    7.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 3648     Full leather             Grey                        8.3
# 3649     Full leather            Black                        8.3
# 3587     Full leather            Black                        8.3

# %%
df[df["make_model"] == "Audi A3"][(df["price(€)"] < lower_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
#      make_model      body_type  price(€)             vat      km  hp(kw)  \
# 3235    Audi A3  Station wagon      5555  VAT deductible  5558.0   110.0
#
#       type  previous_owners inspection_new paint_type  num_of_door  \
# 3235  Used              1.0             No   Metallic          5.0
#
#       num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 3235          5.0       Manual            1968.0        4.0      1465.0
#
#      drive_chain    fuel  co2_emission(g/km) emission_class  \
# 3235       front  Diesel               127.0         Euro 6
#
#                                 comfort_and_convenience  \
# 3235  Air conditioning,Electrical side mirrors,Hill ...
#
#                              entertaintment_and_media  \
# 3235  Bluetooth,CD player,MP3,On-board computer,Radio
#
#                           extras  \
# 3235  Alloy wheels,Voice Control
#
#                                     safety_and_security  gears  age  \
# 3235  ABS,Central door lock with remote control,Driv...    6.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 3235            Cloth             Grey                        4.8

# %%
df.drop(index=[3648,3235], inplace=True)

# %% [markdown]
# ##### Opel Astra

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Astra"]["price(€)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR

# %%
df[df["make_model"] == "Opel Astra"][(df["price(€)"] > upper_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
#       make_model body_type  price(€)             vat    km  hp(kw) type  \
# 7626  Opel Astra   Compact     39433  VAT deductible   1.0   147.0  New
# 7627  Opel Astra   Compact     37995  VAT deductible  10.0   147.0  New
# 7629  Opel Astra   Compact     37995  VAT deductible  10.0   147.0  New
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 7626              1.0             No   Metallic          5.0          5.0
# 7627              1.0             No   Metallic          5.0          5.0
# 7629              1.0             No   Metallic          5.0          5.0
#
#      gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 7626    Automatic            1598.0        4.0      1278.0       front
# 7627    Automatic            1598.0        4.0      1325.0       front
# 7629    Automatic            1598.0        4.0      1325.0       front
#
#          fuel  co2_emission(g/km) emission_class  \
# 7626  Benzine               123.0         Euro 6
# 7627  Benzine               123.0         Euro 6
# 7629  Benzine               149.0         Euro 6
#
#                                 comfort_and_convenience  \
# 7626  Air conditioning,Armrest,Automatic climate con...
# 7627  Air conditioning,Armrest,Automatic climate con...
# 7629  Air conditioning,Armrest,Automatic climate con...
#
#                                entertaintment_and_media  \
# 7626  Digital radio,Hands-free equipment,On-board co...
# 7627       Hands-free equipment,On-board computer,Radio
# 7629       Hands-free equipment,On-board computer,Radio
#
#                           extras  \
# 7626  Alloy wheels,Voice Control
# 7627                Alloy wheels
# 7629                Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 7626  ABS,Alarm system,Blind spot monitor,Daytime ru...    6.0  0.0
# 7627  Central door lock,Driver-side airbag,Electroni...    6.0  0.0
# 7629  Central door lock,Driver-side airbag,Electroni...    6.0  0.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 7626        alcantara            Black                        6.4
# 7627     Full leather            Black                        5.1
# 7629     Full leather            Black                        5.9

# %%
df[df["make_model"] == "Opel Astra"][(df["price(€)"] < lower_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
#       make_model      body_type  price(€)             vat      km  hp(kw)  \
# 6066  Opel Astra  Station wagon       255  VAT deductible  5563.0   100.0
#
#       type  previous_owners inspection_new paint_type  num_of_door  \
# 6066  Used              1.0             No   Metallic          5.0
#
#       num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 6066          5.0       Manual            1598.0        4.0      1403.0
#
#      drive_chain    fuel  co2_emission(g/km) emission_class  \
# 6066       front  Diesel               101.0         Euro 6
#
#                                 comfort_and_convenience  \
# 6066  Air conditioning,Cruise control,Electrical sid...
#
#                                entertaintment_and_media     extras  \
# 6066  Bluetooth,Hands-free equipment,On-board comput...  Roof rack
#
#                                     safety_and_security  gears  age  \
# 6066  ABS,Central door lock with remote control,Dayt...    6.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 6066            Cloth             Grey                        3.8

# %%
df.drop(index=6066, inplace=True)

# %% [markdown]
# ##### Opel Corsa

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Corsa"]["price(€)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (20732.5, 1432.5)

# %%
df[df["make_model"] == "Opel Corsa"][(df["price(€)"] > upper_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price(€), vat, km, hp(kw), type, previous_owners, inspection_new, paint_type, num_of_door, num_of_seat, gearing_type, displacement(cc), cylinders, weight(kg), drive_chain, fuel, co2_emission(g/km), emission_class, comfort_and_convenience, entertaintment_and_media, extras, safety_and_security, gears, age, upholstery_style, upholstery_color, consumption_comb(100km/l)]
# Index: []

# %%
df[df["make_model"] == "Opel Corsa"][(df["price(€)"] < lower_bound)].sort_values(by="price(€)", ascending=False)[:3]
# Out:
#       make_model body_type  price(€)             vat     km  hp(kw)  type  \
# 8829  Opel Corsa     Other       331  VAT deductible   10.0    66.0   New
# 8828  Opel Corsa   Compact       120  VAT deductible   12.0    66.0   New
# 8594  Opel Corsa    Sedans        13  VAT deductible  123.0    66.0  Used
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 8829              1.0             No   Metallic          5.0          5.0
# 8828              1.0             No   Metallic          5.0          5.0
# 8594              1.0             No   Metallic          3.0          5.0
#
#      gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 8829       Manual             999.0        3.0      1163.0       front
# 8828       Manual             999.0        3.0      1099.0       front
# 8594       Manual            1398.0        4.0      1141.0       front
#
#          fuel  co2_emission(g/km) emission_class  \
# 8829  Benzine               123.0         Euro 6
# 8828  Benzine               107.0         Euro 6
# 8594  Benzine               128.0         Euro 6
#
#                                 comfort_and_convenience  \
# 8829  Air conditioning,Armrest,Automatic climate con...
# 8828  Air conditioning,Automatic climate control,Cru...
# 8594  Air conditioning,Cruise control,Electrical sid...
#
#                                entertaintment_and_media  \
# 8829       Hands-free equipment,On-board computer,Radio
# 8828              Digital radio,On-board computer,Radio
# 8594  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                              extras  \
# 8829     Alloy wheels,Sport package
# 8828  Alloy wheels,Sport suspension
# 8594                   Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 8829  ABS,Central door lock,Driver-side airbag,Elect...    6.0  0.0
# 8828  Central door lock,Daytime running lights,Drive...    6.0  0.0
# 8594  ABS,Adaptive headlights,Central door lock with...    5.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 8829            Cloth            Black                        5.2
# 8828            Cloth            Black                        4.6
# 8594            Cloth            Black                        5.6

# %%
df.drop(index=[8829, 8828, 2594], inplace=True)

# %% [markdown]
# ##### Renault Escape

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Espace"]["price(€)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (51587.5, 7287.5)

# %%
df[df["make_model"] == "Renault Espace"][(df["price(€)"] > upper_bound)].sort_values(by="price(€)", ascending=False)[:6]
# Out:
#            make_model body_type  price(€)             vat      km  hp(kw)  \
# 15826  Renault Espace       Van     68320  VAT deductible  4307.0   118.0
# 15828  Renault Espace       Van     64332  VAT deductible     1.0   165.0
# 15831  Renault Espace       Van     64298  VAT deductible    15.0   165.0
# 15833  Renault Espace       Van     63477  VAT deductible     8.0   147.0
# 15808  Renault Espace       Van     58950  VAT deductible  1136.0   165.0
# 15807  Renault Espace       Van     57990  VAT deductible  5000.0   165.0
#
#                 type  previous_owners inspection_new paint_type  num_of_door  \
# 15826  Demonstration              1.0             No   Metallic          5.0
# 15828            New              1.0             No   Metallic          5.0
# 15831            New              1.0             No   Metallic          5.0
# 15833            New              1.0             No   Metallic          5.0
# 15808  Demonstration              1.0             No   Metallic          5.0
# 15807  Demonstration              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 15826          4.0    Automatic            1598.0        4.0      1647.0
# 15828          7.0    Automatic            1798.0        4.0      1647.0
# 15831          7.0    Automatic            1798.0        4.0      1647.0
# 15833          7.0    Automatic            1618.0        4.0      1621.0
# 15808          7.0    Automatic            1798.0        4.0      1624.0
# 15807          5.0    Automatic            1798.0        4.0      1647.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 15826       front   Diesel               120.0         Euro 6
# 15828       front  Benzine               123.0         Euro 6
# 15831       front  Benzine               123.0         Euro 6
# 15833       front  Benzine               123.0         Euro 6
# 15808       front  Benzine               152.0         Euro 6
# 15807         4WD  Benzine               174.0         Euro 6
#
#                                  comfort_and_convenience  \
# 15826  Air conditioning,Armrest,Automatic climate con...
# 15828  Air conditioning,Armrest,Automatic climate con...
# 15831  Air conditioning,Armrest,Automatic climate con...
# 15833  Air conditioning,Armrest,Automatic climate con...
# 15808  Air conditioning,Armrest,Automatic climate con...
# 15807  Air conditioning,Armrest,Automatic climate con...
#
#                                 entertaintment_and_media  \
# 15826  Bluetooth,CD player,Digital radio,Hands-free e...
# 15828           Digital radio,Hands-free equipment,Radio
# 15831           Digital radio,Hands-free equipment,Radio
# 15833       Hands-free equipment,On-board computer,Radio
# 15808                         Hands-free equipment,Radio
# 15807                  CD player,On-board computer,Radio
#
#                            extras  \
# 15826      Alloy wheels,Roof rack
# 15828  Alloy wheels,Voice Control
# 15831  Alloy wheels,Voice Control
# 15833                Alloy wheels
# 15808  Alloy wheels,Voice Control
# 15807                Alloy wheels
#
#                                      safety_and_security  gears  age  \
# 15826  ABS,Adaptive Cruise Control,Adaptive headlight...    7.0  0.0
# 15828  ABS,Alarm system,Blind spot monitor,Daytime ru...    9.0  0.0
# 15831  ABS,Alarm system,Blind spot monitor,Daytime ru...    6.0  0.0
# 15833  ABS,Alarm system,Central door lock,Daytime run...    7.0  0.0
# 15808  ABS,Adaptive Cruise Control,Alarm system,Blind...    7.0  0.0
# 15807  ABS,Central door lock,Driver-side airbag,Elect...    7.0  0.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 15826     Full leather            Brown                        6.5
# 15828     Full leather            Brown                        7.6
# 15831     Full leather             Grey                        7.6
# 15833            Cloth            Brown                        6.8
# 15808     Full leather            Brown                        6.8
# 15807     Full leather            Brown                        7.6

# %% [markdown]
# ##### Audi A2

# %%
df[df["make_model"] == "Audi A2"]
# Out:
#      make_model body_type  price(€)             vat       km  hp(kw)  \
# 2614    Audi A2  Off-Road     28200  VAT deductible  26166.0    85.0
#
#                 type  previous_owners inspection_new paint_type  num_of_door  \
# 2614  Employee's car              1.0             No   Metallic          5.0
#
#       num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 2614          5.0       Manual            1598.0        3.0      1340.0
#
#      drive_chain    fuel  co2_emission(g/km) emission_class  \
# 2614       front  Diesel               106.0         Euro 6
#
#                                 comfort_and_convenience  \
# 2614  Air conditioning,Armrest,Automatic climate con...
#
#                                entertaintment_and_media        extras  \
# 2614  Bluetooth,CD player,Hands-free equipment,MP3,O...  Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 2614  ABS,Adaptive Cruise Control,Central door lock,...    6.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 2614            Cloth            Black                        4.9

# %%
# there is only one row. because of this i will drop this row.

# %%
df.drop(index=2614, inplace=True)

# %% [markdown]
# ### 2- km column

# %%
df["km"].describe()
# Out:
# count     15912.000000
# mean      36929.109193
# std       37664.579611
# min           0.000000
# 25%        6449.500000
# 50%       24771.500000
# 75%       61168.750000
# max      317000.000000
# Name: km, dtype: float64

# %%
sns.lineplot(data=df, x="age", y="km")
# Out:
# <AxesSubplot:xlabel='age', ylabel='km'>

# %%
plt.figure(figsize=(12,6))

sns.boxplot(data=df, x="make_model", y="km", hue="age")
# Out:
# <AxesSubplot:xlabel='make_model', ylabel='km'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[df["age"] == 0], x="make_model", y="km")
# Out:
# <AxesSubplot:xlabel='make_model', ylabel='km'>

# %%
# I don't know how to deal with km column because there is no standart. It depends on person's life style maybe...
# So I won't do anything to km column

# %% [markdown]
# ### 3- hp(kw) column

# %%
df["hp(kw)"].corr(df["price(€)"])
# Out:
# 0.6937223765827459

# %%
sns.scatterplot(data=df, x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
df["hp(kw)"].describe()
# Out:
# count    15912.000000
# mean        88.360608
# std         26.794709
# min          1.000000
# 25%         66.000000
# 50%         85.000000
# 75%        101.000000
# max        294.000000
# Name: hp(kw), dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="hp(kw)")
# Out:
# <AxesSubplot:xlabel='make_model', ylabel='hp(kw)'>

# %% [markdown]
# ##### Audi A1

# %%
sns.boxplot(data=df[df["make_model"]=="Audi A1"], y="make_model", x="hp(kw)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='make_model'>

# %%
sns.scatterplot(data=df[df["make_model"]=="Audi A1"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Audi A1"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (107.5, 47.5)

# %%
df[df["make_model"] == "Audi A1"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#      make_model      body_type  price(€)               vat        km  hp(kw)  \
# 2390    Audi A1        Compact     28997    VAT deductible   1500.00   147.0
# 2347    Audi A1         Sedans     28990    VAT deductible   4900.00   147.0
# 1926    Audi A1        Compact     28560    VAT deductible     10.00   147.0
# 1928    Audi A1        Compact     28200    VAT deductible  77442.52   147.0
# 1958    Audi A1        Compact     28460    VAT deductible   9999.00   147.0
# 2174    Audi A1        Compact     28860    VAT deductible  77442.52   147.0
# 2176    Audi A1         Sedans     28880    VAT deductible   3100.00   147.0
# 2173    Audi A1         Sedans     28880    VAT deductible   4999.00   147.0
# 713     Audi A1         Sedans     37900    VAT deductible   7000.00   147.0
# 2357    Audi A1        Compact     28940    VAT deductible     10.00   147.0
# 2376    Audi A1        Compact     29181    VAT deductible  77442.52   147.0
# 2379    Audi A1        Compact     29179    VAT deductible   3000.00   147.0
# 2382    Audi A1            Van     29000    VAT deductible   3000.00   147.0
# 2387    Audi A1         Sedans     28998    VAT deductible   5000.00   147.0
# 1582    Audi A1         Sedans     22900    VAT deductible   5050.00   141.0
# 1690    Audi A1         Sedans     22683    VAT deductible   9544.00   141.0
# 1687    Audi A1         Sedans     22690    VAT deductible   6892.00   141.0
# 1660    Audi A1        Compact     21900    VAT deductible    973.00   141.0
# 1642    Audi A1         Sedans     23000  Price negotiable  16000.00   141.0
# 1636    Audi A1        Compact     23090    VAT deductible   9821.00   141.0
# 1591    Audi A1         Sedans     23750    VAT deductible   5911.00   141.0
# 1590    Audi A1         Sedans     23750    VAT deductible   5891.00   141.0
# 1       Audi A1         Sedans     14500  Price negotiable  80000.00   141.0
# 945     Audi A1         Sedans     21430    VAT deductible   9900.00   141.0
# 1022    Audi A1         Sedans     20700  Price negotiable   2700.00   141.0
# 769     Audi A1         Sedans     20000  Price negotiable  33500.00   141.0
# 996     Audi A1         Sedans     20885    VAT deductible   8885.00   141.0
# 1010    Audi A1         Sedans     20490    VAT deductible  45000.00   141.0
# 177     Audi A1         Sedans     17490    VAT deductible  55000.00   141.0
# 1463    Audi A1         Sedans     22980    VAT deductible   7987.00   141.0
# 744     Audi A1          Other     23490    VAT deductible  22001.00   140.0
# 13      Audi A1         Sedans     18399    VAT deductible  45764.00   112.0
# 2353    Audi A1        Compact     28980    VAT deductible  77442.52   110.0
# 2138    Audi A1        Compact     24059    VAT deductible  77442.52   110.0
# 942     Audi A1         Sedans     21460    VAT deductible  26800.00   110.0
# 912     Audi A1        Compact     21490    VAT deductible  25900.00   110.0
# 2175    Audi A1        Compact     28875    VAT deductible     15.00   110.0
# 184     Audi A1         Sedans     17445    VAT deductible  45276.00   110.0
# 200     Audi A1        Compact     17900    VAT deductible  40000.00   110.0
# 408     Audi A1        Compact     15490    VAT deductible  29950.00   110.0
# 2015    Audi A1        Compact     28380    VAT deductible  77442.52   110.0
# 2360    Audi A1         Sedans     28900    VAT deductible   1900.00   110.0
# 2383    Audi A1         Sedans     29000    VAT deductible     10.00   110.0
# 249     Audi A1         Sedans     16999  Price negotiable  52800.00   110.0
# 2063    Audi A1        Compact     26450    VAT deductible     15.00   110.0
# 1565    Audi A1        Compact     23450    VAT deductible  14338.00   110.0
# 2000    Audi A1        Compact     28380    VAT deductible  77442.52   110.0
# 1959    Audi A1        Compact     28460    VAT deductible   5000.00   110.0
# 1585    Audi A1        Compact     23829    VAT deductible   7232.00   110.0
# 946     Audi A1        Compact     21406    VAT deductible  77442.52   110.0
# 960     Audi A1        Compact     20980    VAT deductible      1.00   110.0
# 1890    Audi A1        Compact     24706    VAT deductible  77442.52   110.0
# 1693    Audi A1         Sedans     22568    VAT deductible   6461.00   110.0
# 1692    Audi A1         Sedans     22570    VAT deductible   8500.00   110.0
# 1006    Audi A1        Compact     20500    VAT deductible  12345.00   110.0
# 1656    Audi A1         Sedans     21940    VAT deductible   9998.00   110.0
# 1029    Audi A1  Station wagon     20650    VAT deductible  24900.00   110.0
# 1635    Audi A1        Compact     23200    VAT deductible      1.00   110.0
# 1620    Audi A1        Compact     22260    VAT deductible      1.00   110.0
# 1612    Audi A1         Sedans     22440    VAT deductible   4560.00   110.0
# 1038    Audi A1        Compact     20582    VAT deductible  77442.52   110.0
# 1641    Audi A1        Compact     23032    VAT deductible  77442.52   110.0
#
#                 type  previous_owners inspection_new paint_type  num_of_door  \
# 2390   Demonstration              1.0            Yes   Metallic          5.0
# 2347   Demonstration              1.0            Yes   Metallic          4.0
# 1926             New              1.0             No   Metallic          4.0
# 1928             New              1.0             No   Metallic          5.0
# 1958   Demonstration              1.0             No   Metallic          5.0
# 2174             New              1.0             No   Metallic          5.0
# 2176   Demonstration              1.0            Yes   Metallic          4.0
# 2173   Demonstration              1.0             No   Metallic          5.0
# 713             Used              1.0             No   Metallic          5.0
# 2357             New              1.0             No   Metallic          4.0
# 2376             New              0.0             No   Metallic          5.0
# 2379   Demonstration              1.0             No   Metallic          5.0
# 2382   Demonstration              1.0             No   Metallic          5.0
# 2387   Demonstration              1.0            Yes   Metallic          5.0
# 1582            Used              1.0            Yes   Metallic          4.0
# 1690  Employee's car              1.0             No   Metallic          4.0
# 1687            Used              1.0            Yes   Metallic          5.0
# 1660            Used              1.0            Yes   Metallic          5.0
# 1642            Used              2.0             No   Metallic          5.0
# 1636            Used              1.0            Yes   Metallic          2.0
# 1591            Used              1.0            Yes   Metallic          5.0
# 1590            Used              1.0            Yes   Metallic          5.0
# 1               Used              1.0             No   Metallic          3.0
# 945             Used              1.0             No   Metallic          3.0
# 1022            Used              1.0             No   Metallic          5.0
# 769             Used              1.0             No   Metallic          5.0
# 996             Used              1.0            Yes   Metallic          5.0
# 1010            Used              1.0             No  Uni/basic          5.0
# 177             Used              2.0             No   Metallic          3.0
# 1463            Used              1.0             No   Metallic          5.0
# 744             Used              1.0             No   Metallic          5.0
# 13              Used              1.0             No   Metallic          3.0
# 2353             New              1.0            Yes   Metallic          5.0
# 2138             New              1.0             No   Metallic          5.0
# 942             Used              1.0            Yes   Metallic          5.0
# 912             Used              1.0            Yes   Metallic          4.0
# 2175  Pre-registered              1.0             No   Metallic          5.0
# 184             Used              1.0            Yes   Metallic          4.0
# 200             Used              2.0             No   Metallic          4.0
# 408             Used              1.0             No   Metallic          3.0
# 2015             New              1.0            Yes   Metallic          5.0
# 2360            Used              1.0             No   Metallic          5.0
# 2383  Pre-registered              1.0             No  Uni/basic          5.0
# 249             Used              1.0            Yes   Metallic          5.0
# 2063  Pre-registered              1.0             No   Metallic          5.0
# 1565            Used              1.0             No   Metallic          5.0
# 2000             New              1.0            Yes   Metallic          5.0
# 1959   Demonstration              1.0            Yes   Metallic          4.0
# 1585            Used              1.0            Yes   Metallic          4.0
# 946              New              1.0             No   Metallic          5.0
# 960              New              1.0             No   Metallic          5.0
# 1890             New              1.0             No   Metallic          5.0
# 1693            Used              1.0             No   Metallic          4.0
# 1692            Used              1.0             No   Metallic          5.0
# 1006            Used              1.0            Yes   Metallic          3.0
# 1656            Used              1.0             No   Metallic          5.0
# 1029            Used              2.0            Yes   Metallic          5.0
# 1635             New              1.0             No   Metallic          5.0
# 1620             New              1.0             No   Metallic          5.0
# 1612            Used              1.0             No   Metallic          5.0
# 1038             New              1.0             No   Metallic          5.0
# 1641             New              1.0             No   Metallic          5.0
#
#       num_of_seat    gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 2390          5.0       Automatic            1984.0        4.0      1335.0
# 2347          5.0       Automatic            1984.0        4.0      1335.0
# 1926          5.0       Automatic            1984.0        4.0      1335.0
# 1928          5.0       Automatic            1984.0        4.0      1180.0
# 1958          5.0       Automatic            1984.0        3.0      1200.0
# 2174          5.0       Automatic            1984.0        4.0      1180.0
# 2176          5.0       Automatic            1984.0        3.0      1200.0
# 2173          5.0       Automatic            1984.0        3.0      1200.0
# 713           5.0  Semi-automatic            1984.0        4.0      1240.0
# 2357          5.0       Automatic            1984.0        4.0      1335.0
# 2376          5.0       Automatic            1984.0        4.0      1180.0
# 2379          5.0       Automatic            1984.0        4.0      1180.0
# 2382          4.0       Automatic            1984.0        3.0      1124.0
# 2387          4.0       Automatic            1984.0        4.0      1335.0
# 1582          5.0       Automatic            1798.0        3.0      1680.0
# 1690          5.0       Automatic            1798.0        4.0      1180.0
# 1687          5.0       Automatic            1798.0        4.0      1180.0
# 1660          4.0       Automatic            1798.0        4.0      1140.0
# 1642          4.0       Automatic            1798.0        4.0      1280.0
# 1636          3.0       Automatic            1798.0        4.0      1240.0
# 1591          5.0       Automatic            1798.0        3.0      1195.0
# 1590          5.0       Automatic            1798.0        3.0      1195.0
# 1             4.0       Automatic            1798.0        4.0      1255.0
# 945           4.0       Automatic            1798.0        4.0      1255.0
# 1022          4.0       Automatic            1798.0        4.0      1280.0
# 769           4.0  Semi-automatic            1798.0        4.0      1280.0
# 996           5.0       Automatic            1798.0        4.0      1705.0
# 1010          4.0       Automatic            1798.0        4.0      1280.0
# 177           5.0       Automatic            1798.0        4.0      1255.0
# 1463          5.0       Automatic            1798.0        4.0      1230.0
# 744           5.0  Semi-automatic             999.0        4.0      1205.0
# 13            4.0       Automatic            1395.0        4.0      1250.0
# 2353          5.0       Automatic            1498.0        4.0      1240.0
# 2138          5.0       Automatic            1498.0        4.0      1180.0
# 942           5.0       Automatic            1395.0        4.0      1135.0
# 912           4.0       Automatic            1395.0        4.0      1155.0
# 2175          5.0       Automatic            1498.0        4.0      1240.0
# 184           5.0       Automatic            1395.0        4.0      1165.0
# 200           4.0       Automatic            1395.0        3.0      1250.0
# 408           4.0       Automatic            1395.0        4.0      1205.0
# 2015          4.0       Automatic            1498.0        3.0      1200.0
# 2360          5.0       Automatic            1498.0        4.0      1655.0
# 2383          5.0       Automatic            1498.0        3.0      1230.0
# 249           4.0       Automatic            1395.0        4.0      1230.0
# 2063          5.0       Automatic            1498.0        4.0      1240.0
# 1565          4.0       Automatic            1395.0        4.0      1230.0
# 2000          5.0       Automatic            1498.0        3.0      1200.0
# 1959          4.0       Automatic            1498.0        4.0      1240.0
# 1585          5.0       Automatic            1395.0        4.0      1090.0
# 946           5.0       Automatic            1498.0        4.0      1180.0
# 960           5.0       Automatic            1498.0        4.0      1240.0
# 1890          5.0       Automatic            1498.0        4.0      1180.0
# 1693          5.0       Automatic            1395.0        4.0      1180.0
# 1692          5.0       Automatic            1395.0        4.0      1180.0
# 1006          4.0       Automatic            1395.0        4.0      1230.0
# 1656          5.0       Automatic            1395.0        4.0      1200.0
# 1029          5.0       Automatic            1395.0        4.0      1215.0
# 1635          5.0       Automatic            1498.0        4.0      1240.0
# 1620          5.0       Automatic            1498.0        4.0      1240.0
# 1612          5.0       Automatic            1395.0        4.0      1220.0
# 1038          5.0       Automatic            1498.0        4.0      1180.0
# 1641          5.0       Automatic            1498.0        4.0      1180.0
#
#      drive_chain     fuel  co2_emission(g/km) emission_class  \
# 2390       front  Benzine               136.0         Euro 6
# 2347       front  Benzine               136.0         Euro 6
# 1926       front  Benzine               142.0         Euro 6
# 1928       front  Benzine               123.0         Euro 6
# 1958       front  Benzine               137.0         Euro 6
# 2174       front  Benzine               137.0         Euro 6
# 2176       front  Benzine               136.0         Euro 6
# 2173       front  Benzine               136.0         Euro 6
# 713        front  Benzine               136.0         Euro 6
# 2357       front  Benzine               142.0         Euro 6
# 2376       front  Benzine               123.0         Euro 6
# 2379       front  Benzine               136.0         Euro 6
# 2382       front  Benzine               123.0         Euro 6
# 2387       front  Benzine               136.0         Euro 6
# 1582       front  Benzine               129.0         Euro 6
# 1690       front  Benzine               129.0         Euro 6
# 1687       front  Benzine               129.0         Euro 6
# 1660       front  Benzine               134.0         Euro 6
# 1642       front  Benzine               129.0         Euro 6
# 1636       front  Benzine               134.0         Euro 6
# 1591       front  Benzine               123.0         Euro 6
# 1590       front  Benzine               123.0         Euro 6
# 1          front  Benzine               129.0         Euro 6
# 945        front  Benzine               129.0         Euro 6
# 1022       front  Benzine               129.0         Euro 6
# 769        front  Benzine               129.0         Euro 6
# 996        front  Benzine               129.0         Euro 6
# 1010       front  Benzine               129.0         Euro 6
# 177        front  Benzine               137.0         Euro 6
# 1463       front  Benzine               129.0         Euro 6
# 744        front  Benzine               134.0         Euro 6
# 13         front  Benzine               123.0         Euro 6
# 2353       front  Benzine               116.0         Euro 6
# 2138       front  Benzine               123.0         Euro 6
# 942        front  Benzine               109.0         Euro 6
# 912        front  Benzine               109.0         Euro 6
# 2175       front  Benzine               115.0         Euro 6
# 184        front  Benzine               109.0         Euro 6
# 200        front  Benzine               116.0         Euro 6
# 408        front  Benzine               109.0         Euro 6
# 2015       front  Benzine               115.0         Euro 6
# 2360       front  Benzine               115.0         Euro 6
# 2383       front  Benzine               115.0         Euro 6
# 249        front  Benzine               109.0         Euro 6
# 2063       front  Benzine               115.0         Euro 6
# 1565       front  Benzine               109.0         Euro 6
# 2000       front  Benzine               115.0         Euro 6
# 1959       front  Benzine               115.0         Euro 6
# 1585       front  Benzine               109.0         Euro 6
# 946        front  Benzine               123.0         Euro 6
# 960        front  Benzine               116.0         Euro 6
# 1890       front  Benzine               123.0         Euro 6
# 1693       front  Benzine               109.0         Euro 6
# 1692       front  Benzine               109.0         Euro 6
# 1006       front  Benzine               109.0         Euro 6
# 1656       front  Benzine               109.0         Euro 6
# 1029       front  Benzine               109.0         Euro 6
# 1635       front  Benzine               116.0         Euro 6
# 1620       front  Benzine               116.0         Euro 6
# 1612       front  Benzine               111.0         Euro 6
# 1038       front  Benzine               123.0         Euro 6
# 1641       front  Benzine               123.0         Euro 6
#
#                                 comfort_and_convenience  \
# 2390  Air conditioning,Armrest,Automatic climate con...
# 2347  Air conditioning,Armrest,Automatic climate con...
# 1926  Air conditioning,Automatic climate control,Ele...
# 1928  Air conditioning,Armrest,Automatic climate con...
# 1958  Air conditioning,Armrest,Automatic climate con...
# 2174  Air conditioning,Armrest,Automatic climate con...
# 2176  Air conditioning,Armrest,Automatic climate con...
# 2173              Electrical side mirrors,Power windows
# 713   Air conditioning,Seat ventilation,Split rear s...
# 2357  Air conditioning,Armrest,Automatic climate con...
# 2376  Air conditioning,Armrest,Automatic climate con...
# 2379  Air conditioning,Armrest,Automatic climate con...
# 2382  Air conditioning,Automatic climate control,Cru...
# 2387  Air conditioning,Armrest,Automatic climate con...
# 1582  Air conditioning,Armrest,Automatic climate con...
# 1690  Air conditioning,Armrest,Automatic climate con...
# 1687  Air conditioning,Armrest,Automatic climate con...
# 1660  Air conditioning,Armrest,Automatic climate con...
# 1642  Air conditioning,Armrest,Automatic climate con...
# 1636  Air conditioning,Armrest,Automatic climate con...
# 1591  Air conditioning,Armrest,Automatic climate con...
# 1590  Air conditioning,Armrest,Automatic climate con...
# 1     Air conditioning,Automatic climate control,Hil...
# 945   Air conditioning,Automatic climate control,Cru...
# 1022  Leather steering wheel,Lumbar support,Power wi...
# 769   Air conditioning,Armrest,Automatic climate con...
# 996   Air conditioning,Armrest,Automatic climate con...
# 1010  Air conditioning,Hill Holder,Leather steering ...
# 177   Air conditioning,Armrest,Automatic climate con...
# 1463  Air conditioning,Armrest,Automatic climate con...
# 744   Air conditioning,Automatic climate control,Cru...
# 13    Air conditioning,Automatic climate control,Cru...
# 2353  Air conditioning,Armrest,Automatic climate con...
# 2138  Air conditioning,Armrest,Automatic climate con...
# 942   Air conditioning,Armrest,Automatic climate con...
# 912   Air conditioning,Automatic climate control,Cru...
# 2175  Leather steering wheel,Navigation system,Park ...
# 184   Air conditioning,Armrest,Cruise control,Electr...
# 200   Air conditioning,Armrest,Automatic climate con...
# 408   Air conditioning,Automatic climate control,Hil...
# 2015  Air conditioning,Armrest,Automatic climate con...
# 2360                     Air conditioning,Power windows
# 2383  Air conditioning,Automatic climate control,Ele...
# 249   Air conditioning,Armrest,Automatic climate con...
# 2063  Park Distance Control,Parking assist system se...
# 1565  Air conditioning,Armrest,Automatic climate con...
# 2000  Air conditioning,Armrest,Automatic climate con...
# 1959  Air conditioning,Armrest,Automatic climate con...
# 1585  Air conditioning,Armrest,Automatic climate con...
# 946   Air conditioning,Armrest,Automatic climate con...
# 960   Air conditioning,Electrical side mirrors,Hill ...
# 1890  Air conditioning,Armrest,Automatic climate con...
# 1693  Air conditioning,Armrest,Automatic climate con...
# 1692  Air conditioning,Armrest,Automatic climate con...
# 1006  Air conditioning,Armrest,Automatic climate con...
# 1656  Air conditioning,Armrest,Automatic climate con...
# 1029  Air conditioning,Armrest,Automatic climate con...
# 1635  Air conditioning,Electrical side mirrors,Hill ...
# 1620  Air conditioning,Electrical side mirrors,Hill ...
# 1612  Air conditioning,Armrest,Automatic climate con...
# 1038  Air conditioning,Armrest,Automatic climate con...
# 1641  Air conditioning,Armrest,Automatic climate con...
#
#                                entertaintment_and_media  \
# 2390  Bluetooth,Hands-free equipment,MP3,On-board co...
# 2347  Bluetooth,CD player,Hands-free equipment,On-bo...
# 1926  Bluetooth,CD player,Hands-free equipment,Sound...
# 1928  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1958  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 2174  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 2176  Bluetooth,Hands-free equipment,On-board comput...
# 2173                                  On-board computer
# 713                                     Bluetooth,Radio
# 2357  Bluetooth,Digital radio,Hands-free equipment,S...
# 2376  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 2379  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 2382  Bluetooth,On-board computer,Radio,Sound system...
# 2387        Bluetooth,Hands-free equipment,Sound system
# 1582  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1690  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1687  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1660  Bluetooth,CD player,MP3,On-board computer,Radi...
# 1642  Bluetooth,CD player,Hands-free equipment,On-bo...
# 1636  Bluetooth,CD player,Digital radio,Hands-free e...
# 1591  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1590  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1     Bluetooth,Hands-free equipment,On-board comput...
# 945         Bluetooth,CD player,On-board computer,Radio
# 1022                                              Radio
# 769                                               Radio
# 996   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1010                            On-board computer,Radio
# 177   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1463  Bluetooth,Hands-free equipment,MP3,Radio,Sound...
# 744                         CD player,On-board computer
# 13                    Bluetooth,On-board computer,Radio
# 2353  Bluetooth,Hands-free equipment,MP3,On-board co...
# 2138  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 942   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 912   Bluetooth,Hands-free equipment,On-board comput...
# 2175                                              Radio
# 184   Bluetooth,CD player,Hands-free equipment,MP3,R...
# 200   Bluetooth,CD player,Hands-free equipment,On-bo...
# 408         Bluetooth,CD player,On-board computer,Radio
# 2015  Bluetooth,Digital radio,Hands-free equipment,O...
# 2360                                              Radio
# 2383                                          Bluetooth
# 249   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 2063                                              Radio
# 1565  Bluetooth,CD player,Hands-free equipment,MP3,R...
# 2000  Bluetooth,Digital radio,Hands-free equipment,O...
# 1959                                            MP3,USB
# 1585  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 946   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 960   Bluetooth,Hands-free equipment,On-board comput...
# 1890  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1693  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1692  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1006  Bluetooth,CD player,MP3,On-board computer,Radi...
# 1656  Bluetooth,Hands-free equipment,MP3,On-board co...
# 1029  CD player,Hands-free equipment,On-board comput...
# 1635  Bluetooth,Hands-free equipment,On-board comput...
# 1620  Bluetooth,Hands-free equipment,On-board comput...
# 1612  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1038  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 1641  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                                  extras  \
# 2390  Alloy wheels,Sport package,Sport seats,Touch s...
# 2347  Alloy wheels,Sport package,Sport seats,Sport s...
# 1926             Alloy wheels,Sport seats,Voice Control
# 1928                                       Alloy wheels
# 1958  Alloy wheels,Sport package,Sport seats,Sport s...
# 2174  Alloy wheels,Catalytic Converter,Sport seats,S...
# 2176          Alloy wheels,Sport seats,Sport suspension
# 2173  Catalytic Converter,Sport package,Sport suspen...
# 713                       Alloy wheels,Sport suspension
# 2357  Alloy wheels,Shift paddles,Sport seats,Sport s...
# 2376                                       Alloy wheels
# 2379  Alloy wheels,Sport package,Sport seats,Sport s...
# 2382                                       Alloy wheels
# 2387  Alloy wheels,Sport package,Sport seats,Sport s...
# 1582             Alloy wheels,Sport seats,Voice Control
# 1690  Alloy wheels,Catalytic Converter,Sport package...
# 1687  Alloy wheels,Shift paddles,Sport seats,Sport s...
# 1660  Catalytic Converter,Shift paddles,Sport packag...
# 1642  Alloy wheels,Shift paddles,Sport package,Sport...
# 1636  Alloy wheels,Catalytic Converter,Sport package...
# 1591  Alloy wheels,Sport seats,Sport suspension,Voic...
# 1590  Alloy wheels,Sport seats,Sport suspension,Voic...
# 1     Alloy wheels,Sport seats,Sport suspension,Voic...
# 945           Alloy wheels,Sport seats,Sport suspension
# 1022                       Sport seats,Sport suspension
# 769                                        Alloy wheels
# 996   Alloy wheels,Catalytic Converter,Sport seats,S...
# 1010          Alloy wheels,Sport seats,Sport suspension
# 177   Alloy wheels,Sport package,Sport seats,Sport s...
# 1463                                        Sport seats
# 744                               Roof rack,Sport seats
# 13            Alloy wheels,Sport seats,Sport suspension
# 2353  Alloy wheels,Catalytic Converter,Sport seats,V...
# 2138                                       Alloy wheels
# 942   Alloy wheels,Catalytic Converter,Sport package...
# 912                      Alloy wheels,Cab or rented Car
# 2175                                       Alloy wheels
# 184   Alloy wheels,Sport package,Sport seats,Sport s...
# 200   Alloy wheels,Sport package,Sport seats,Sport s...
# 408                            Alloy wheels,Sport seats
# 2015  Alloy wheels,Catalytic Converter,Sport seats,V...
# 2360                                       Alloy wheels
# 2383                                       Alloy wheels
# 249   Alloy wheels,Catalytic Converter,Sport package...
# 2063                                       Alloy wheels
# 1565  Alloy wheels,Catalytic Converter,Sport seats,V...
# 2000  Alloy wheels,Catalytic Converter,Sport seats,V...
# 1959                                       Alloy wheels
# 1585  Alloy wheels,Sport package,Sport seats,Sport s...
# 946                                        Alloy wheels
# 960                                        Alloy wheels
# 1890                                       Alloy wheels
# 1693  Alloy wheels,Catalytic Converter,Sport package...
# 1692  Alloy wheels,Catalytic Converter,Sport seats,V...
# 1006          Alloy wheels,Sport seats,Sport suspension
# 1656  Alloy wheels,Catalytic Converter,Sport seats,V...
# 1029          Alloy wheels,Sport seats,Sport suspension
# 1635                      Alloy wheels,Sport suspension
# 1620                                       Alloy wheels
# 1612  Alloy wheels,Sport seats,Sport suspension,Voic...
# 1038                                       Alloy wheels
# 1641                                       Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 2390  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2347  ABS,Daytime running lights,Driver-side airbag,...    6.0  0.0
# 1926  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 1928  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 1958  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2174  ABS,Central door lock,Daytime running lights,D...    6.0  0.0
# 2176  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2173  ABS,Central door lock,Driver-side airbag,Elect...    7.0  0.0
# 713   ABS,Alarm system,Central door lock,Driver-side...    6.0  0.0
# 2357  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2376  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2379  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2382  ABS,Electronic stability control,Isofix,Power ...    6.0  0.0
# 2387  Daytime running lights,Driver-side airbag,Elec...    6.0  0.0
# 1582  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1690  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1687  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1660  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1642  ABS,Central door lock with remote control,Dayt...    7.0  1.0
# 1636  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1591  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1590  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1     ABS,Central door lock,Central door lock with r...    7.0  2.0
# 945   ABS,Central door lock,Daytime running lights,D...    7.0  2.0
# 1022  ABS,Central door lock with remote control,Dayt...    7.0  2.0
# 769   ABS,Central door lock,Daytime running lights,D...    7.0  2.0
# 996   ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1010  ABS,Central door lock with remote control,Dayt...    7.0  2.0
# 177   ABS,Central door lock,Daytime running lights,D...    7.0  3.0
# 1463  Daytime running lights,Driver-side airbag,Elec...    7.0  1.0
# 744   Adaptive Cruise Control,Central door lock,Driv...    7.0  2.0
# 13    ABS,Adaptive headlights,Central door lock,Dayt...    7.0  3.0
# 2353  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2138  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 942   ABS,Central door lock,Daytime running lights,D...    5.0  2.0
# 912   ABS,Central door lock,Daytime running lights,D...    7.0  2.0
# 2175                                     LED Headlights    6.0  0.0
# 184   ABS,Central door lock,Central door lock with r...    7.0  3.0
# 200   ABS,Adaptive headlights,Central door lock,Dayt...    7.0  3.0
# 408   ABS,Adaptive headlights,Central door lock,Driv...    7.0  3.0
# 2015  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2360  ABS,Central door lock,Passenger-side airbag,Po...    7.0  0.0
# 2383  ABS,Central door lock,Central door lock with r...    6.0  0.0
# 249   ABS,Central door lock with remote control,Dayt...    7.0  3.0
# 2063                                     LED Headlights    7.0  0.0
# 1565  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 2000  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 1959  Adaptive Cruise Control,Daytime running lights...    7.0  0.0
# 1585  ABS,Central door lock,Central door lock with r...    7.0  1.0
# 946   ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 960   ABS,Daytime running lights,Driver-side airbag,...    7.0  0.0
# 1890  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 1693  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1692  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1006  ABS,Central door lock,Daytime running lights,D...    7.0  2.0
# 1656  ABS,Daytime running lights,Driver-side airbag,...    6.0  1.0
# 1029  ABS,Central door lock,Daytime running lights,D...    7.0  2.0
# 1635  ABS,Daytime running lights,Driver-side airbag,...    7.0  0.0
# 1620  ABS,Daytime running lights,Driver-side airbag,...    7.0  0.0
# 1612  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
# 1038  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
# 1641  ABS,Central door lock,Daytime running lights,D...    7.0  0.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 2390            Cloth            Black                        6.0
# 2347            Cloth             Grey                        6.0
# 1926     Part leather            Black                        6.0
# 1928     Part leather            Black                        6.0
# 1958            Cloth             Grey                        6.0
# 2174            Cloth             Grey                        6.0
# 2176            Cloth             Grey                        6.0
# 2173            Cloth             Grey                        6.0
# 713             Cloth             Grey                        6.0
# 2357     Part leather            Black                        6.0
# 2376            Cloth            Black                        6.0
# 2379            Cloth             Grey                        6.0
# 2382            Cloth            Black                        4.6
# 2387            Cloth             Grey                        6.0
# 1582            Cloth            Black                        5.6
# 1690            Cloth            Black                        5.6
# 1687            Cloth             Grey                        5.6
# 1660            Cloth            Black                        5.8
# 1642            Cloth            Black                        5.6
# 1636     Part leather            Black                        5.8
# 1591            Cloth            Black                        4.6
# 1590            Cloth            Black                        4.6
# 1               Cloth             Grey                        5.6
# 945             Cloth            Black                        5.6
# 1022            Cloth            Black                        5.6
# 769             Cloth            Other                        5.6
# 996             Cloth             Grey                        5.6
# 1010            Cloth             Grey                        5.6
# 177             Cloth            Black                        5.8
# 1463            Cloth            Other                        5.6
# 744             Cloth            Black                        5.8
# 13       Part leather            Black                        4.6
# 2353     Part leather            Black                        5.1
# 2138            Cloth            Black                        5.0
# 942             Cloth            Black                        4.7
# 912             Cloth             Grey                        4.7
# 2175            Cloth             Grey                        5.1
# 184      Part leather            Black                        4.7
# 200      Part leather            Black                        5.0
# 408             Cloth            Other                        4.7
# 2015            Cloth             Grey                        5.1
# 2360            Cloth             Grey                        5.0
# 2383            Other            Black                        5.0
# 249             Cloth            Black                        4.7
# 2063            Cloth             Grey                        5.1
# 1565            Cloth             Grey                        4.7
# 2000            Cloth             Grey                        5.1
# 1959            Cloth            Black                        5.1
# 1585            Cloth            Black                        4.7
# 946      Part leather            Black                        5.0
# 960            Velour            Black                        5.1
# 1890            Cloth             Grey                        5.0
# 1693            Cloth            Black                        4.7
# 1692            Cloth            Black                        4.7
# 1006            Cloth            Black                        4.7
# 1656            Cloth             Grey                        4.7
# 1029            Cloth            Black                        4.7
# 1635           Velour            Black                        5.1
# 1620           Velour            Black                        5.1
# 1612            Other            Other                        4.7
# 1038     Part leather            Black                        5.0
# 1641     Part leather            Black                        5.0

# %%
df[df["make_model"] == "Audi A1"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)[:6]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price(€), vat, km, hp(kw), type, previous_owners, inspection_new, paint_type, num_of_door, num_of_seat, gearing_type, displacement(cc), cylinders, weight(kg), drive_chain, fuel, co2_emission(g/km), emission_class, comfort_and_convenience, entertaintment_and_media, extras, safety_and_security, gears, age, upholstery_style, upholstery_color, consumption_comb(100km/l)]
# Index: []

# %%
df.loc[(df["make_model"] == "Audi A1") & (df["hp(kw)"] > 120), "hp(kw)"] =np.nan

# %%
sns.boxplot(data=df[df["make_model"]=="Audi A1"], y="make_model", x="hp(kw)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='make_model'>

# %% [markdown]
# ##### Audi A3

# %%
sns.boxplot(data=df[df["make_model"]=="Audi A3"], y="make_model", x="hp(kw)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='make_model'>

# %%
sns.scatterplot(data=df[df["make_model"]=="Audi A3"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Audi A3"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (91.0, 75.0)

# %%
df[df["make_model"] == "Audi A3"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#      make_model      body_type  price(€)             vat        km  hp(kw)  \
# 3595    Audi A3  Station wagon     63900  VAT deductible      10.0   294.0
# 3606    Audi A3         Sedans     49900  VAT deductible   17234.0   294.0
# 3587    Audi A3         Sedans     64900  VAT deductible   35000.0   294.0
# 3649    Audi A3        Compact     67600  VAT deductible   37747.0   294.0
# 3590    Audi A3         Sedans     62900  VAT deductible     700.0   294.0
# ...         ...            ...       ...             ...       ...     ...
# 3282    Audi A3        Compact     13500  VAT deductible  100832.0    92.0
# 4236    Audi A3  Station wagon     18200  VAT deductible   19500.0    92.0
# 2995    Audi A3        Compact     13500  VAT deductible  100832.0    92.0
# 2994    Audi A3        Compact     13500  VAT deductible  110396.0    92.0
# 3105    Audi A3         Sedans     15030  VAT deductible   95671.0    92.0
#
#       type  previous_owners inspection_new paint_type  num_of_door  \
# 3595  Used              1.0             No   Metallic          5.0
# 3606  Used              1.0             No   Metallic          5.0
# 3587  Used              1.0             No   Metallic          5.0
# 3649  Used              1.0             No   Metallic          5.0
# 3590  Used              1.0             No   Metallic          5.0
# ...    ...              ...            ...        ...          ...
# 3282  Used              1.0             No   Metallic          5.0
# 4236  Used              1.0             No   Metallic          5.0
# 2995  Used              1.0             No   Metallic          5.0
# 2994  Used              1.0             No   Metallic          5.0
# 3105  Used              1.0             No   Metallic          5.0
#
#       num_of_seat    gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 3595          5.0  Semi-automatic            2480.0        5.0      1585.0
# 3606          5.0  Semi-automatic            2480.0        5.0      1585.0
# 3587          5.0  Semi-automatic            2480.0        5.0      1585.0
# 3649          5.0  Semi-automatic            2480.0        5.0      1485.0
# 3590          5.0  Semi-automatic            2480.0        5.0      1585.0
# ...           ...             ...               ...        ...         ...
# 3282          5.0          Manual            1395.0        4.0      1280.0
# 4236          5.0          Manual            1395.0        4.0      1280.0
# 2995          5.0          Manual            1395.0        4.0      1280.0
# 2994          5.0          Manual            1395.0        4.0      1280.0
# 3105          5.0          Manual            1400.0        4.0      1260.0
#
#      drive_chain     fuel  co2_emission(g/km) emission_class  \
# 3595       front  Benzine               189.0         Euro 6
# 3606         4WD  Benzine               189.0         Euro 6
# 3587       front  Benzine               189.0         Euro 6
# 3649         4WD  Benzine               189.0         Euro 6
# 3590       front  Benzine               194.0         Euro 6
# ...          ...      ...                 ...            ...
# 3282       front  Benzine               119.0         Euro 6
# 4236       front  Benzine               122.0         Euro 6
# 2995       front  Benzine               119.0         Euro 6
# 2994       front  Benzine               119.0         Euro 6
# 3105       front  Benzine               123.0         Euro 6
#
#                                 comfort_and_convenience  \
# 3595  Air conditioning,Armrest,Automatic climate con...
# 3606  Air conditioning,Seat ventilation,Split rear s...
# 3587  Air conditioning,Seat ventilation,Split rear s...
# 3649  Air conditioning,Armrest,Automatic climate con...
# 3590  Air conditioning,Seat ventilation,Split rear s...
# ...                                                 ...
# 3282         Air conditioning,Armrest,Start-stop system
# 4236  Air conditioning,Electrical side mirrors,Hill ...
# 2995         Air conditioning,Armrest,Start-stop system
# 2994                      Multi-function steering wheel
# 3105  Air conditioning,Automatic climate control,Cru...
#
#                                entertaintment_and_media  \
# 3595  Bluetooth,CD player,Digital radio,Hands-free e...
# 3606                                              Radio
# 3587                                              Radio
# 3649                  CD player,On-board computer,Radio
# 3590                                    Bluetooth,Radio
# ...                                                 ...
# 3282                                  On-board computer
# 4236                                  On-board computer
# 2995                                  On-board computer
# 2994                                  On-board computer
# 3105  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                                  extras  \
# 3595  Alloy wheels,Shift paddles,Ski bag,Sport packa...
# 3606                                       Alloy wheels
# 3587                                       Alloy wheels
# 3649  Alloy wheels,Roof rack,Sport seats,Sport suspe...
# 3590                                       Alloy wheels
# ...                                                 ...
# 3282                                       Alloy wheels
# 4236          Alloy wheels,Sport seats,Sport suspension
# 2995                                       Alloy wheels
# 2994                                       Alloy wheels
# 3105                                  Cab or rented Car
#
#                                     safety_and_security  gears  age  \
# 3595  ABS,Adaptive Cruise Control,Adaptive headlight...    7.0  0.0
# 3606  Adaptive Cruise Control,Alarm system,Central d...    7.0  1.0
# 3587  Adaptive Cruise Control,Alarm system,Central d...    7.0  1.0
# 3649  ABS,Alarm system,Central door lock,Driver-side...    7.0  2.0
# 3590  ABS,Adaptive Cruise Control,Alarm system,Centr...    7.0  0.0
# ...                                                 ...    ...  ...
# 3282  Daytime running lights,Driver drowsiness detec...    6.0  3.0
# 4236  ABS,Central door lock with remote control,Driv...    6.0  2.0
# 2995  Daytime running lights,Driver drowsiness detec...    6.0  3.0
# 2994                    Tire pressure monitoring system    6.0  3.0
# 3105  ABS,Central door lock,Daytime running lights,D...    6.0  3.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 3595     Part leather            Black                        8.3
# 3606     Full leather            Black                        8.3
# 3587     Full leather            Black                        8.3
# 3649     Full leather            Black                        8.3
# 3590     Full leather            Black                        8.3
# ...               ...              ...                        ...
# 3282            Cloth            Black                        5.1
# 4236            Cloth            Black                        5.3
# 2995            Cloth            Black                        5.1
# 2994            Cloth            Black                        5.1
# 3105            Cloth             Grey                        5.1
#
# [657 rows x 29 columns]

# %%
df[df["make_model"] == "Audi A3"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)[:6]
# Out:
#      make_model body_type  price(€)             vat       km  hp(kw)  type  \
# 3913    Audi A3    Sedans     20440  VAT deductible  24000.0     9.0  Used
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 3913              1.0             No   Metallic          5.0          5.0
#
#      gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 3913    Automatic            1968.0        4.0      1360.0       front
#
#         fuel  co2_emission(g/km) emission_class  \
# 3913  Diesel               106.0         Euro 6
#
#                                 comfort_and_convenience  \
# 3913  Air conditioning,Automatic climate control,Cru...
#
#                                entertaintment_and_media        extras  \
# 3913  Bluetooth,CD player,Hands-free equipment,MP3,O...  Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 3913  ABS,Central door lock,Daytime running lights,D...    7.0  2.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 3913            Cloth            Black                        4.0

# %%
df.loc[df.index == 3913, "hp(kw)"]= np.nan

# %% [markdown]
# ##### Opel Astra

# %%
sns.boxplot(data=df[df["make_model"]=="Opel Astra"], y="make_model", x="hp(kw)");

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Astra"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (153.5, 37.5)

# %%
df[df["make_model"] == "Opel Astra"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)[:3]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price(€), vat, km, hp(kw), type, previous_owners, inspection_new, paint_type, num_of_door, num_of_seat, gearing_type, displacement(cc), cylinders, weight(kg), drive_chain, fuel, co2_emission(g/km), emission_class, comfort_and_convenience, entertaintment_and_media, extras, safety_and_security, gears, age, upholstery_style, upholstery_color, consumption_comb(100km/l)]
# Index: []

# %%
df[df["make_model"] == "Opel Astra"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)[:10]
# Out:
#       make_model      body_type  price(€)             vat       km  hp(kw)  \
# 6005  Opel Astra  Station wagon     11600  VAT deductible  73860.0     1.0
# 6034  Opel Astra  Station wagon     11600  VAT deductible  76010.0     1.0
# 6946  Opel Astra  Station wagon     11900  VAT deductible  70090.0     1.0
# 7014  Opel Astra         Sedans     11700  VAT deductible  79993.0     1.0
# 7016  Opel Astra         Sedans     11700  VAT deductible  62384.0     1.0
# 7018  Opel Astra         Sedans     11700  VAT deductible  77272.0     1.0
# 7019  Opel Astra         Sedans     11700  VAT deductible  69035.0     1.0
#
#       type  previous_owners inspection_new paint_type  num_of_door  \
# 6005  Used              1.0             No   Metallic          5.0
# 6034  Used              1.0             No   Metallic          5.0
# 6946  Used              1.0             No   Metallic          5.0
# 7014  Used              1.0             No   Metallic          5.0
# 7016  Used              1.0             No   Metallic          5.0
# 7018  Used              1.0             No   Metallic          5.0
# 7019  Used              1.0             No   Metallic          5.0
#
#       num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 6005          5.0    Automatic             998.0        3.0      1985.0
# 6034          5.0    Automatic             998.0        4.0      1425.0
# 6946          5.0       Manual            1598.0        4.0      1328.0
# 7014          5.0       Manual            1364.0        4.0      1350.0
# 7016          5.0       Manual            1364.0        4.0      1350.0
# 7018          5.0       Manual            1364.0        4.0      1350.0
# 7019          5.0       Manual            1364.0        4.0      1350.0
#
#      drive_chain     fuel  co2_emission(g/km) emission_class  \
# 6005       front  Benzine               123.0         Euro 5
# 6034       front  Benzine               123.0         Euro 6
# 6946       front   Diesel               106.0         Euro 6
# 7014       front  Benzine               123.0         Euro 6
# 7016       front  Benzine               123.0         Euro 6
# 7018       front  Benzine               123.0         Euro 6
# 7019       front  Benzine               123.0         Euro 6
#
#                                 comfort_and_convenience  \
# 6005  Air conditioning,Electrical side mirrors,Leath...
# 6034  Air conditioning,Electrical side mirrors,Leath...
# 6946  Air conditioning,Automatic climate control,Cru...
# 7014  Air conditioning,Automatic climate control,Cru...
# 7016  Air conditioning,Automatic climate control,Cru...
# 7018  Air conditioning,Automatic climate control,Cru...
# 7019  Air conditioning,Automatic climate control,Cru...
#
#                              entertaintment_and_media        extras  \
# 6005            Bluetooth,On-board computer,Radio,USB     Roof rack
# 6034            Bluetooth,On-board computer,Radio,USB     Roof rack
# 6946  Bluetooth,CD player,On-board computer,Radio,USB     Roof rack
# 7014                                  CD player,Radio  Alloy wheels
# 7016                                  CD player,Radio  Alloy wheels
# 7018                                  CD player,Radio  Alloy wheels
# 7019                                  CD player,Radio  Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 6005  Alarm system,Central door lock,Driver-side air...    6.0  2.0
# 6034  Alarm system,Central door lock,Driver-side air...    6.0  2.0
# 6946  Central door lock,Driver-side airbag,Electroni...    6.0  2.0
# 7014  Driver-side airbag,Electronic stability contro...    6.0  2.0
# 7016  Driver-side airbag,Electronic stability contro...    6.0  2.0
# 7018  Driver-side airbag,Electronic stability contro...    6.0  2.0
# 7019  Driver-side airbag,Electronic stability contro...    6.0  2.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 6005            Cloth             Grey                        5.6
# 6034            Cloth            Black                        5.6
# 6946            Other            Other                        3.9
# 7014            Other            Other                        5.4
# 7016            Other            Other                        5.4
# 7018            Other            Other                        5.4
# 7019            Other            Other                        5.4

# %%
df.loc[(df["make_model"]=="Opel Astra") & (df["hp(kw)"] < lower_bound), "hp(kw)"] = np.nan

# %% [markdown]
# ##### Opel Corsa

# %%
sns.boxplot(data=df[df["make_model"]=="Opel Corsa"], y="make_model", x="hp(kw)");

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Corsa"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (88.5, 28.5)

# %%
df[df["make_model"] == "Opel Corsa"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)[:3]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price(€), vat, km, hp(kw), type, previous_owners, inspection_new, paint_type, num_of_door, num_of_seat, gearing_type, displacement(cc), cylinders, weight(kg), drive_chain, fuel, co2_emission(g/km), emission_class, comfort_and_convenience, entertaintment_and_media, extras, safety_and_security, gears, age, upholstery_style, upholstery_color, consumption_comb(100km/l)]
# Index: []

# %%
df[df["make_model"] == "Opel Corsa"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#       make_model body_type  price(€)               vat       km  hp(kw)  type  \
# 9285  Opel Corsa    Sedans      8300    VAT deductible  58912.0     1.0  Used
# 9287  Opel Corsa    Sedans      8300    VAT deductible  53522.0     1.0  Used
# 9288  Opel Corsa    Sedans      8300    VAT deductible  60386.0     1.0  Used
# 9289  Opel Corsa    Sedans      8300    VAT deductible  59217.0     1.0  Used
# 9290  Opel Corsa    Sedans      8300    VAT deductible  51318.0     1.0  Used
# 9292  Opel Corsa    Sedans      8300    VAT deductible  53390.0     1.0  Used
# 9299  Opel Corsa    Sedans      8300  Price negotiable  47140.0     1.0  Used
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 9285              1.0             No   Metallic          5.0          5.0
# 9287              1.0             No   Metallic          5.0          5.0
# 9288              1.0             No   Metallic          5.0          5.0
# 9289              1.0             No   Metallic          5.0          5.0
# 9290              1.0             No   Metallic          5.0          5.0
# 9292              1.0             No   Metallic          5.0          5.0
# 9299              1.0             No   Metallic          5.0          5.0
#
#      gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 9285       Manual            1229.0        4.0      1199.0       front
# 9287       Manual            1229.0        4.0      1199.0       front
# 9288       Manual            1229.0        4.0      1199.0       front
# 9289       Manual            1229.0        4.0      1199.0       front
# 9290       Manual            1229.0        4.0      1199.0       front
# 9292       Manual            1229.0        4.0      1163.0       front
# 9299       Manual            1229.0        4.0      1163.0       front
#
#          fuel  co2_emission(g/km) emission_class  \
# 9285  Benzine               123.0         Euro 6
# 9287  Benzine               123.0         Euro 6
# 9288  Benzine               123.0         Euro 6
# 9289  Benzine               123.0         Euro 6
# 9290  Benzine               123.0         Euro 6
# 9292  Benzine               123.0         Euro 6
# 9299  Benzine               123.0         Euro 6
#
#                                 comfort_and_convenience  \
# 9285  Air conditioning,Automatic climate control,Cru...
# 9287  Air conditioning,Automatic climate control,Cru...
# 9288  Air conditioning,Automatic climate control,Cru...
# 9289  Air conditioning,Automatic climate control,Cru...
# 9290  Air conditioning,Automatic climate control,Cru...
# 9292  Air conditioning,Automatic climate control,Cru...
# 9299  Air conditioning,Automatic climate control,Cru...
#
#                              entertaintment_and_media        extras  \
# 9285  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9287  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9288  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9289  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9290  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9292  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
# 9299  Bluetooth,CD player,On-board computer,Radio,USB  Alloy wheels
#
#                                     safety_and_security  gears  age  \
# 9285  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9287  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9288  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9289  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9290  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9292  Alarm system,Central door lock,Driver-side air...    5.0  2.0
# 9299  Alarm system,Central door lock,Driver-side air...    5.0  2.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 9285            Other            Black                       5.35
# 9287            Other            Black                       5.35
# 9288            Other            Black                       5.35
# 9289            Other            Black                       5.35
# 9290            Other            Black                       5.35
# 9292            Other            Black                       5.35
# 9299            Cloth             Grey                       5.35

# %%
df.loc[(df["make_model"]=="Opel Corsa") & (df["hp(kw)"] < lower_bound), "hp(kw)"] = np.nan

# %% [markdown]
# ##### Opel Insignia

# %%
sns.boxplot(data=df[df["make_model"]=="Opel Insignia"], y="make_model", x="hp(kw)");

# %%
sns.scatterplot(data=df[df["make_model"]=="Opel Insignia"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Insignia"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (162.5, 62.5)

# %%
df[df["make_model"] == "Opel Insignia"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)[:3]
# Out:
#           make_model      body_type  price(€)             vat        km  \
# 10513  Opel Insignia  Station wagon     17990  VAT deductible  145000.0
# 11117  Opel Insignia  Station wagon     11980  VAT deductible   89982.0
# 10789  Opel Insignia         Sedans     11600  VAT deductible   68000.0
#
#        hp(kw)  type  previous_owners inspection_new paint_type  num_of_door  \
# 10513   239.0  Used              1.0             No   Metallic          4.0
# 11117   195.0  Used              1.0             No   Metallic          5.0
# 10789   191.0  Used              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 10513          5.0    Automatic            1598.0        4.0      1701.0
# 11117          5.0       Manual            1956.0        4.0      1733.0
# 10789          5.0    Automatic            1998.0        4.0      1513.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 10513         4WD  Benzine               253.0         Euro 6
# 11117       front   Diesel               130.0         Euro 6
# 10789       front  Benzine               197.0         Euro 6
#
#                                  comfort_and_convenience  \
# 10513  Air conditioning,Armrest,Automatic climate con...
# 11117  Air conditioning,Automatic climate control,Cru...
# 10789  Air conditioning,Armrest,Automatic climate con...
#
#                                 entertaintment_and_media  \
# 10513  Bluetooth,CD player,Digital radio,Hands-free e...
# 11117  Bluetooth,CD player,Digital radio,Hands-free e...
# 10789                    CD player,MP3,On-board computer
#
#                                                   extras  \
# 10513  Alloy wheels,Roof rack,Shift paddles,Sport pac...
# 11117                            Roof rack,Trailer hitch
# 10789                     Alloy wheels,Roof rack,Ski bag
#
#                                      safety_and_security  gears  age  \
# 10513  ABS,Adaptive Cruise Control,Blind spot monitor...    6.0  3.0
# 11117  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  0.0
# 10789  ABS,Central door lock with remote control,Driv...    6.0  2.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 10513     Full leather            Black                       11.0
# 11117            Cloth            Black                        4.9
# 10789            Cloth            Black                        8.6

# %%
df[df["make_model"] == "Opel Insignia"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#           make_model      body_type  price(€)             vat       km  \
# 10468  Opel Insignia  Station wagon     15300  VAT deductible  77125.0
# 10579  Opel Insignia  Station wagon     16400  VAT deductible  78762.0
# 10580  Opel Insignia  Station wagon     16400  VAT deductible  68525.0
# 10610  Opel Insignia  Station wagon     15300  VAT deductible  62800.0
#
#        hp(kw)  type  previous_owners inspection_new paint_type  num_of_door  \
# 10468     1.0  Used              1.0             No   Metallic          5.0
# 10579     1.0  Used              1.0             No   Metallic          5.0
# 10580     1.0  Used              1.0             No   Metallic          5.0
# 10610     1.0  Used              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 10468          5.0    Automatic            1598.0        4.0      1743.0
# 10579          5.0    Automatic            1598.0        4.0      1901.0
# 10580          5.0    Automatic            1598.0        4.0      1901.0
# 10610          5.0    Automatic            1598.0        4.0      1743.0
#
#       drive_chain    fuel  co2_emission(g/km) emission_class  \
# 10468       front  Diesel               106.0         Euro 6
# 10579       front  Diesel               106.0         Euro 6
# 10580       front  Diesel               106.0         Euro 6
# 10610       front  Diesel               106.0         Euro 6
#
#                                  comfort_and_convenience  \
# 10468  Air conditioning,Automatic climate control,Cru...
# 10579  Air conditioning,Automatic climate control,Cru...
# 10580  Air conditioning,Automatic climate control,Cru...
# 10610  Air conditioning,Automatic climate control,Cru...
#
#                               entertaintment_and_media  \
# 10468  Bluetooth,CD player,On-board computer,Radio,USB
# 10579  Bluetooth,CD player,On-board computer,Radio,USB
# 10580  Bluetooth,CD player,On-board computer,Radio,USB
# 10610  Bluetooth,CD player,On-board computer,Radio,USB
#
#                        extras  \
# 10468  Alloy wheels,Roof rack
# 10579  Alloy wheels,Roof rack
# 10580  Alloy wheels,Roof rack
# 10610  Alloy wheels,Roof rack
#
#                                      safety_and_security  gears  age  \
# 10468  Alarm system,Central door lock,Driver-side air...    6.0  2.0
# 10579  Alarm system,Central door lock,Driver-side air...    6.0  2.0
# 10580  Alarm system,Central door lock,Driver-side air...    6.0  2.0
# 10610  Alarm system,Central door lock,Driver-side air...    6.0  2.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 10468     Part leather             Grey                        5.2
# 10579            Cloth            Black                        5.2
# 10580            Cloth            Black                        5.2
# 10610            Cloth            Black                        5.2

# %%
df.loc[df.index == 10513, "hp(kw)"] = np.nan

# %%
df.loc[(df["make_model"] == "Opel Insignia") & (df["hp(kw)"] < lower_bound), "hp(kw)"] = np.nan

# %% [markdown]
# ##### Renault Clio

# %%
sns.boxplot(data=df[df["make_model"]=="Renault Clio"], y="make_model", x="hp(kw)");

# %%
sns.scatterplot(data=df[df["make_model"]=="Renault Clio"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Clio"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (135.0, 7.0)

# %%
df[df["make_model"] == "Renault Clio"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)[:5]
# Out:
#          make_model body_type  price(€)               vat       km  hp(kw)  \
# 14415  Renault Clio    Sedans     18490    VAT deductible  10564.0   164.0
# 14422  Renault Clio    Sedans     18490    VAT deductible  10564.0   164.0
# 14417  Renault Clio    Sedans     18490    VAT deductible  10564.0   164.0
# 13870  Renault Clio    Sedans     18490  Price negotiable  10564.0   164.0
# 13872  Renault Clio    Sedans     18490  Price negotiable  10564.0   164.0
#
#        type  previous_owners inspection_new paint_type  num_of_door  \
# 14415  Used              1.0             No   Metallic          4.0
# 14422  Used              1.0             No   Metallic          4.0
# 14417  Used              1.0             No   Metallic          4.0
# 13870  Used              1.0             No   Metallic          4.0
# 13872  Used              1.0             No   Metallic          4.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 14415          5.0    Automatic            1618.0        4.0      1279.0
# 14422          5.0    Automatic            1618.0        4.0      1279.0
# 14417          5.0    Automatic            1618.0        4.0      1279.0
# 13870          5.0    Automatic            1618.0        4.0      1280.0
# 13872          5.0    Automatic            1618.0        4.0      1280.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 14415         4WD  Benzine               140.0         Euro 6
# 14422         4WD  Benzine               140.0         Euro 6
# 14417         4WD  Benzine               140.0         Euro 6
# 13870       front  Benzine               140.0         Euro 6
# 13872       front  Benzine               140.0         Euro 6
#
#                                  comfort_and_convenience  \
# 14415  Air conditioning,Cruise control,Electrical sid...
# 14422  Air conditioning,Cruise control,Electrical sid...
# 14417  Air conditioning,Cruise control,Electrical sid...
# 13870  Air conditioning,Cruise control,Electrical sid...
# 13872  Air conditioning,Cruise control,Electrical sid...
#
#                                 entertaintment_and_media  \
# 14415  Bluetooth,Digital radio,Hands-free equipment,O...
# 14422  Bluetooth,Digital radio,Hands-free equipment,O...
# 14417  Bluetooth,Digital radio,Hands-free equipment,O...
# 13870  Bluetooth,Digital radio,Hands-free equipment,O...
# 13872  Bluetooth,Digital radio,Hands-free equipment,O...
#
#                                                   extras  \
# 14415  Alloy wheels,Shift paddles,Sport package,Sport...
# 14422  Alloy wheels,Shift paddles,Sport package,Sport...
# 14417  Alloy wheels,Shift paddles,Sport package,Sport...
# 13870  Alloy wheels,Shift paddles,Sport package,Sport...
# 13872  Alloy wheels,Shift paddles,Sport package,Sport...
#
#                                      safety_and_security  gears  age  \
# 14415  ABS,Central door lock,Daytime running lights,D...    6.0  1.0
# 14422  ABS,Central door lock,Daytime running lights,D...    6.0  1.0
# 14417  ABS,Central door lock,Daytime running lights,D...    6.0  1.0
# 13870  ABS,Central door lock,Daytime running lights,D...    6.0  1.0
# 13872  ABS,Central door lock,Daytime running lights,D...    6.0  1.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 14415            Cloth            Black                        5.9
# 14422            Cloth            Black                        5.9
# 14417            Cloth            Black                        5.9
# 13870            Cloth            Black                        5.9
# 13872            Cloth            Black                        5.9

# %%
df[df["make_model"] == "Renault Clio"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#          make_model body_type  price(€)             vat      km  hp(kw)  type  \
# 13885  Renault Clio   Compact      8990  VAT deductible  9751.0     4.0  Used
#
#        previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 13885              2.0             No   Metallic          5.0          5.0
#
#       gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 13885       Manual            1197.0        4.0      1165.0       front
#
#           fuel  co2_emission(g/km) emission_class comfort_and_convenience  \
# 13885  Benzine               123.0         Euro 6           Power windows
#
#       entertaintment_and_media        extras  \
# 13885        On-board computer  Alloy wheels
#
#                                      safety_and_security  gears  age  \
# 13885  ABS,Driver-side airbag,Immobilizer,Passenger-s...    6.0  2.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 13885     Part leather            Black                        5.4

# %%
df.loc[df.index == 13885, "hp(kw)"] = np.nan

# %% [markdown]
# ##### Renault Duster

# %%
sns.boxplot(data=df[df["make_model"]=="Renault Duster"], y="make_model", x="hp(kw)");

# %%
sns.scatterplot(data=df[df["make_model"]=="Renault Duster"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
df[df["make_model"]=="Renault Duster"]["make_model"].count()
# Out:
# 34

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Duster"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (77.0, 77.0)

# %%
df[df["make_model"] == "Renault Duster"][(df["hp(kw)"] > upper_bound)].sort_values(by="hp(kw)", ascending=False)[:3]
# Out:
#            make_model body_type  price(€)             vat        km  hp(kw)  \
# 14921  Renault Duster  Off-Road     12000  VAT deductible  77442.52    81.0
#
#       type  previous_owners inspection_new paint_type  num_of_door  \
# 14921  New              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 14921          5.0       Manual            1600.0        4.0      1165.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 14921         4WD  Benzine               123.0         Euro 4
#
#                                  comfort_and_convenience  \
# 14921  Air conditioning,Electrically heated windshiel...
#
#                                 entertaintment_and_media     extras  \
# 14921  CD player,Digital radio,MP3,On-board computer,...  Roof rack
#
#                                      safety_and_security  gears  age  \
# 14921  ABS,Central door lock,Driver-side airbag,Elect...    6.0  0.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 14921            Cloth            Black                       10.0

# %%
df.loc[df.index == 14921, "hp(kw)"] = np.nan

# %% [markdown]
# ##### Renault Espace

# %%
sns.boxplot(data=df[df["make_model"]=="Renault Espace"], y="make_model", x="hp(kw)");

# %%
sns.scatterplot(data=df[df["make_model"]=="Renault Espace"], x="hp(kw)", y="price(€)")
# Out:
# <AxesSubplot:xlabel='hp(kw)', ylabel='price(€)'>

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Espace"]["hp(kw)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (190.5, 74.5)

# %%
df[df["make_model"] == "Renault Espace"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)
# Out:
#            make_model body_type  price(€)             vat       km  hp(kw)  \
# 15155  Renault Espace    Sedans     23800  VAT deductible  56340.0     1.0
# 15156  Renault Espace    Sedans     23800  VAT deductible  69600.0     1.0
#
#        type  previous_owners inspection_new paint_type  num_of_door  \
# 15155  Used              1.0             No   Metallic          5.0
# 15156  Used              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 15155          5.0    Automatic            1589.0        4.0      2044.0
# 15156          5.0    Automatic            1589.0        4.0      2044.0
#
#       drive_chain    fuel  co2_emission(g/km) emission_class  \
# 15155       front  Diesel               106.0         Euro 6
# 15156       front  Diesel               106.0         Euro 6
#
#                                  comfort_and_convenience  \
# 15155  Air conditioning,Automatic climate control,Cru...
# 15156  Air conditioning,Automatic climate control,Cru...
#
#                               entertaintment_and_media  \
# 15155  Bluetooth,CD player,On-board computer,Radio,USB
# 15156  Bluetooth,CD player,On-board computer,Radio,USB
#
#                                         extras  \
# 15155  Alloy wheels,Touch screen,Voice Control
# 15156  Alloy wheels,Touch screen,Voice Control
#
#                                      safety_and_security  gears  age  \
# 15155  Alarm system,Central door lock,Driver-side air...    7.0  2.0
# 15156  Alarm system,Central door lock,Driver-side air...    7.0  2.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 15155     Part leather             Grey                        4.7
# 15156     Part leather             Grey                        4.7

# %%
df[df["make_model"] == "Renault Espace"][(df["hp(kw)"] < lower_bound)].sort_values(by="hp(kw)", ascending=False)["hp(kw)"]
# Out:
# 15155    1.0
# 15156    1.0
# Name: hp(kw), dtype: float64

# %%
df.loc[(df["make_model"] == "Renault Espace") & (df["hp(kw)"] < lower_bound), "hp(kw)"] = np.nan

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="hp(kw)");

# %% [markdown]
# ### 4- previous_owners column

# %%
df["previous_owners"].corr(df["price(€)"])
# Out:
# -0.1304727319750901

# %%
sns.lineplot(data=df, x="previous_owners", y="age")
# Out:
# <AxesSubplot:xlabel='previous_owners', ylabel='age'>

# %%
df["previous_owners"].value_counts()
# Out:
# 1.0    14383
# 2.0     1180
# 0.0      318
# 3.0       29
# 4.0        2
# Name: previous_owners, dtype: int64

# %% [markdown]
# ### 5- num_of_door column

# %%
df["num_of_door"].corr(df["price(€)"])
# Out:
# 0.16539853376912603

# %%
df["num_of_door"].value_counts()
# Out:
# 5.0    11723
# 4.0     3111
# 3.0      853
# 2.0      222
# 1.0        2
# 7.0        1
# Name: num_of_door, dtype: int64

# %%
df[(df["num_of_door"] == 7)]
# Out:
#            make_model body_type  price(€)               vat       km  hp(kw)  \
# 15202  Renault Espace       Van     21600  Price negotiable  78000.0   118.0
#
#        type  previous_owners inspection_new paint_type  num_of_door  \
# 15202  Used              1.0             No   Metallic          7.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 15202          5.0    Automatic            1598.0        4.0      1734.0
#
#       drive_chain    fuel  co2_emission(g/km) emission_class  \
# 15202       front  Diesel               120.0         Euro 6
#
#                                  comfort_and_convenience  \
# 15202  Air conditioning,Armrest,Automatic climate con...
#
#                                 entertaintment_and_media  \
# 15202  Bluetooth,Digital radio,MP3,On-board computer,...
#
#                           extras  \
# 15202  Alloy wheels,Touch screen
#
#                                      safety_and_security  gears  age  \
# 15202  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  3.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 15202     Full leather            Brown                        4.6

# %%
df[(df["make_model"] == "Renault Espace") & (df["body_type"] == "Van")].sort_values(by="num_of_door", ascending=False)
# Out:
#            make_model body_type  price(€)               vat        km  hp(kw)  \
# 15202  Renault Espace       Van     21600  Price negotiable   78000.0   118.0
# 14928  Renault Espace       Van     17500    VAT deductible  141000.0   118.0
# 15625  Renault Espace       Van     29500    VAT deductible   16500.0   118.0
# 15601  Renault Espace       Van     30965    VAT deductible      11.0   165.0
# 15602  Renault Espace       Van     30950    VAT deductible       1.0   118.0
# ...               ...       ...       ...               ...       ...     ...
# 15079  Renault Espace       Van     25490    VAT deductible   49606.0   147.0
# 15080  Renault Espace       Van     25490    VAT deductible   49606.0   147.0
# 15081  Renault Espace       Van     25490    VAT deductible   49606.0   147.0
# 15082  Renault Espace       Van     25490    VAT deductible   49606.0   147.0
# 15686  Renault Espace       Van     38890    VAT deductible   16800.0   165.0
#
#                  type  previous_owners inspection_new paint_type  num_of_door  \
# 15202            Used              1.0             No   Metallic          7.0
# 14928            Used              1.0             No   Metallic          5.0
# 15625            Used              1.0             No   Metallic          5.0
# 15601             New              1.0            Yes   Metallic          5.0
# 15602  Pre-registered              1.0             No   Metallic          5.0
# ...               ...              ...            ...        ...          ...
# 15079            Used              2.0             No   Metallic          4.0
# 15080            Used              2.0             No   Metallic          4.0
# 15081            Used              2.0             No   Metallic          4.0
# 15082            Used              2.0             No   Metallic          4.0
# 15686            Used              1.0             No   Metallic          4.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 15202          5.0    Automatic            1598.0        4.0      1734.0
# 14928          7.0    Automatic            1598.0        4.0      1734.0
# 15625          5.0    Automatic            1598.0        4.0      1685.0
# 15601          5.0    Automatic            1798.0        4.0      1659.0
# 15602          5.0    Automatic            1997.0        4.0      1758.0
# ...            ...          ...               ...        ...         ...
# 15079          7.0    Automatic            1618.0        4.0      1634.0
# 15080          7.0    Automatic            1618.0        4.0      1634.0
# 15081          7.0    Automatic            1618.0        4.0      1634.0
# 15082          7.0    Automatic            1618.0        4.0      1634.0
# 15686          7.0    Automatic            1598.0        4.0      1659.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 15202       front   Diesel               120.0         Euro 6
# 14928       front   Diesel               120.0         Euro 6
# 15625       front   Diesel               106.0         Euro 6
# 15601       front  Benzine               168.0         Euro 6
# 15602       front   Diesel               135.0         Euro 6
# ...           ...      ...                 ...            ...
# 15079         4WD  Benzine               153.0         Euro 6
# 15080         4WD  Benzine               153.0         Euro 6
# 15081         4WD  Benzine               153.0         Euro 6
# 15082         4WD  Benzine               153.0         Euro 6
# 15686       front  Benzine               152.0         Euro 6
#
#                                  comfort_and_convenience  \
# 15202  Air conditioning,Armrest,Automatic climate con...
# 14928                                   Air conditioning
# 15625  Air conditioning,Automatic climate control,Cru...
# 15601  Air conditioning,Automatic climate control,Cru...
# 15602  Air conditioning,Automatic climate control,Cru...
# ...                                                  ...
# 15079  Air conditioning,Armrest,Automatic climate con...
# 15080  Air conditioning,Armrest,Automatic climate con...
# 15081  Air conditioning,Armrest,Automatic climate con...
# 15082  Air conditioning,Armrest,Automatic climate con...
# 15686  Air conditioning,Armrest,Automatic climate con...
#
#                                 entertaintment_and_media  \
# 15202  Bluetooth,Digital radio,MP3,On-board computer,...
# 14928  Bluetooth,Hands-free equipment,On-board comput...
# 15625                        Bluetooth,On-board computer
# 15601  Bluetooth,Hands-free equipment,On-board comput...
# 15602  Bluetooth,Digital radio,Hands-free equipment,R...
# ...                                                  ...
# 15079  Bluetooth,Digital radio,Hands-free equipment,O...
# 15080  Bluetooth,Digital radio,Hands-free equipment,O...
# 15081  Bluetooth,Digital radio,Hands-free equipment,O...
# 15082  Bluetooth,Digital radio,Hands-free equipment,O...
# 15686  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                   extras  \
# 15202                          Alloy wheels,Touch screen
# 14928                                       Alloy wheels
# 15625                                       Alloy wheels
# 15601                                       Touch screen
# 15602                          Alloy wheels,Touch screen
# ...                                                  ...
# 15079                          Alloy wheels,Touch screen
# 15080                          Alloy wheels,Touch screen
# 15081                          Alloy wheels,Touch screen
# 15082                          Alloy wheels,Touch screen
# 15686  Alloy wheels,Shift paddles,Ski bag,Sport seats...
#
#                                      safety_and_security  gears  age  \
# 15202  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  3.0
# 14928  ABS,Central door lock,Daytime running lights,D...    6.0  3.0
# 15625  ABS,Central door lock,Driver-side airbag,Isofi...    7.0  1.0
# 15601  ABS,Blind spot monitor,Central door lock,Dayti...    7.0  0.0
# 15602  ABS,Blind spot monitor,Central door lock,Drive...    6.0  0.0
# ...                                                  ...    ...  ...
# 15079  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  2.0
# 15080  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  2.0
# 15081  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  2.0
# 15082  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  2.0
# 15686  ABS,Adaptive Cruise Control,Adaptive headlight...    7.0  1.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 15202     Full leather            Brown                        4.6
# 14928     Full leather            Brown                        4.6
# 15625     Part leather            Brown                        4.7
# 15601            Cloth            Black                        7.4
# 15602            Cloth            Black                        5.1
# ...                ...              ...                        ...
# 15079            Cloth            Black                        6.8
# 15080            Cloth            Black                        6.8
# 15081            Cloth            Black                        6.8
# 15082            Cloth            Black                        6.8
# 15686     Full leather            Brown                        6.8
#
# [803 rows x 29 columns]

# %%
df.loc[(df["num_of_door"] == 7), "num_of_door"] = np.nan

# %%
df[(df["num_of_door"] == 1)]
# Out:
#          make_model body_type  price(€)             vat        km  hp(kw)  \
# 13782  Renault Clio   Compact      8500  VAT deductible   41493.0    55.0
# 13785  Renault Clio   Compact      8500  VAT deductible  120620.0    66.0
#
#        type  previous_owners inspection_new paint_type  num_of_door  \
# 13782  Used              1.0             No   Metallic          1.0
# 13785  Used              1.0             No   Metallic          1.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 13782          5.0       Manual            1461.0        4.0      1165.0
# 13785          5.0       Manual            1461.0        4.0      1165.0
#
#       drive_chain    fuel  co2_emission(g/km) emission_class  \
# 13782       front  Diesel               106.0         Euro 6
# 13785       front  Diesel               106.0         Euro 6
#
#                                  comfort_and_convenience  \
# 13782  Air conditioning,Cruise control,Hill Holder,Mu...
# 13785  Air conditioning,Automatic climate control,Cru...
#
#                                 entertaintment_and_media        extras  \
# 13782  Bluetooth,Hands-free equipment,On-board comput...  Alloy wheels
# 13785                        Bluetooth,On-board computer  Alloy wheels
#
#                                      safety_and_security  gears  age  \
# 13782  ABS,Central door lock,Daytime running lights,D...    6.0  3.0
# 13785                                  Central door lock    6.0  3.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 13782            Cloth             Grey                        3.3
# 13785            Cloth             Grey                        3.3

# %%
df[(df["make_model"] == "Renault Clio") & (df["body_type"] == "Compact")].sort_values(by="num_of_door", ascending=False)
# Out:
#          make_model body_type  price(€)               vat        km  hp(kw)  \
# 14052  Renault Clio   Compact     16295    VAT deductible     100.0    88.0
# 14045  Renault Clio   Compact     16490  Price negotiable    7770.0    87.0
# 14027  Renault Clio   Compact     17900    VAT deductible   15293.0    87.0
# 14010  Renault Clio   Compact     18440    VAT deductible     150.0    87.0
# 14002  Renault Clio   Compact      8750    VAT deductible   47000.0    55.0
# ...             ...       ...       ...               ...       ...     ...
# 14154  Renault Clio   Compact      9880    VAT deductible   26230.0    54.0
# 14164  Renault Clio   Compact      9900    VAT deductible    6523.0    54.0
# 14893  Renault Clio   Compact     10880    VAT deductible     150.0    56.0
# 13785  Renault Clio   Compact      8500    VAT deductible  120620.0    66.0
# 13782  Renault Clio   Compact      8500    VAT deductible   41493.0    55.0
#
#                  type  previous_owners inspection_new paint_type  num_of_door  \
# 14052  Pre-registered              1.0             No   Metallic          5.0
# 14045            Used              1.0             No   Metallic          5.0
# 14027            Used              2.0             No   Metallic          5.0
# 14010  Pre-registered              1.0             No   Metallic          5.0
# 14002            Used              1.0             No   Metallic          5.0
# ...               ...              ...            ...        ...          ...
# 14154            Used              1.0             No   Metallic          4.0
# 14164   Demonstration              1.0             No   Metallic          4.0
# 14893            Used              1.0             No   Metallic          4.0
# 13785            Used              1.0             No   Metallic          1.0
# 13782            Used              1.0             No   Metallic          1.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 14052          5.0    Automatic            1197.0        4.0      1065.0
# 14045          5.0    Automatic            1197.0        4.0      1065.0
# 14027          5.0    Automatic            1197.0        4.0      1065.0
# 14010          5.0    Automatic            1197.0        4.0      1090.0
# 14002          5.0       Manual            1461.0        4.0      1090.0
# ...            ...          ...               ...        ...         ...
# 14154          5.0       Manual            1149.0        3.0      1165.0
# 14164          5.0       Manual            1149.0        3.0      1052.0
# 14893          5.0       Manual             898.0        3.0      1127.0
# 13785          5.0       Manual            1461.0        4.0      1165.0
# 13782          5.0       Manual            1461.0        4.0      1165.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 14052       front  Benzine               120.0         Euro 6
# 14045       front  Benzine               120.0         Euro 6
# 14027       front  Benzine               120.0         Euro 6
# 14010       front  Benzine               120.0         Euro 6
# 14002       front   Diesel                85.0         Euro 6
# ...           ...      ...                 ...            ...
# 14154       front  Benzine               133.0         Euro 6
# 14164       front  Benzine               127.0         Euro 6
# 14893       front  Benzine               113.0         Euro 6
# 13785       front   Diesel               106.0         Euro 6
# 13782       front   Diesel               106.0         Euro 6
#
#                                  comfort_and_convenience  \
# 14052  Air conditioning,Automatic climate control,Ele...
# 14045  Air conditioning,Armrest,Cruise control,Electr...
# 14027  Air conditioning,Automatic climate control,Cru...
# 14010  Air conditioning,Automatic climate control,Cru...
# 14002  Air conditioning,Cruise control,Hill Holder,Mu...
# ...                                                  ...
# 14154  Air conditioning,Armrest,Cruise control,Electr...
# 14164  Air conditioning,Cruise control,Electrical sid...
# 14893  Air conditioning,Cruise control,Electrical sid...
# 13785  Air conditioning,Automatic climate control,Cru...
# 13782  Air conditioning,Cruise control,Hill Holder,Mu...
#
#                                 entertaintment_and_media  \
# 14052                     Bluetooth,Hands-free equipment
# 14045  Bluetooth,Digital radio,Hands-free equipment,M...
# 14027                                  On-board computer
# 14010  Bluetooth,Digital radio,Hands-free equipment,M...
# 14002                        Bluetooth,On-board computer
# ...                                                  ...
# 14154  Bluetooth,CD player,Hands-free equipment,On-bo...
# 14164  Bluetooth,CD player,Hands-free equipment,On-bo...
# 14893  Bluetooth,Hands-free equipment,On-board comput...
# 13785                        Bluetooth,On-board computer
# 13782  Bluetooth,Hands-free equipment,On-board comput...
#
#                                               extras  \
# 14052                                   Alloy wheels
# 14045               Catalytic Converter,Touch screen
# 14027                                   Alloy wheels
# 14010  Alloy wheels,Catalytic Converter,Touch screen
# 14002                                   Alloy wheels
# ...                                              ...
# 14154                     Touch screen,Voice Control
# 14164                                   Alloy wheels
# 14893                                   Alloy wheels
# 13785                                   Alloy wheels
# 13782                                   Alloy wheels
#
#                                      safety_and_security  gears  age  \
# 14052  ABS,Driver-side airbag,Electronic stability co...    6.0  1.0
# 14045  ABS,Central door lock,Daytime running lights,D...    6.0  2.0
# 14027  ABS,Central door lock,Driver-side airbag,Elect...    6.0  2.0
# 14010  ABS,Central door lock,Daytime running lights,D...    5.0  0.0
# 14002  ABS,Central door lock,Daytime running lights,D...    5.0  2.0
# ...                                                  ...    ...  ...
# 14154  ABS,Alarm system,Central door lock,Daytime run...    5.0  1.0
# 14164  ABS,Alarm system,Central door lock,Daytime run...    5.0  1.0
# 14893  ABS,Central door lock,Daytime running lights,D...    5.0  0.0
# 13785                                  Central door lock    6.0  3.0
# 13782  ABS,Central door lock,Daytime running lights,D...    6.0  3.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 14052            Cloth            Black                        5.4
# 14045            Cloth            Black                        5.4
# 14027     Part leather            Black                        5.4
# 14010     Part leather            Black                        5.4
# 14002            Cloth            Black                        3.3
# ...                ...              ...                        ...
# 14154            Cloth            Black                        5.6
# 14164            Cloth            Black                        5.6
# 14893            Cloth            Black                        5.0
# 13785            Cloth             Grey                        3.3
# 13782            Cloth             Grey                        3.3
#
# [484 rows x 29 columns]

# %%
df.loc[(df["num_of_door"] == 1), "num_of_door"] = np.nan

# %%
df["num_of_door"].value_counts(dropna=False)
# Out:
# 5.0    11723
# 4.0     3111
# 3.0      853
# 2.0      222
# NaN        3
# Name: num_of_door, dtype: int64

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        condition = (df["make_model"] == makemodel) & (df["body_type"] == bodytype)
        df.loc[condition, "num_of_door"] = df.loc[condition, "num_of_door"].fillna(method="ffill").fillna(method="bfill")

df["num_of_door"] = df["num_of_door"].fillna(method="ffill").fillna(method="bfill")

# %%
df["num_of_door"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 6- num_of_seat column

# %%
df["num_of_seat"].corr(df["price(€)"])
# Out:
# 0.2595669660517991

# %%
df["num_of_seat"].value_counts()
# Out:
# 5.0    14175
# 4.0     1194
# 7.0      409
# 2.0      131
# 6.0        2
# 3.0        1
# Name: num_of_seat, dtype: int64

# %%
df.loc[df["num_of_seat"]==3]
# Out:
#      make_model body_type  price(€)             vat      km  hp(kw)  type  \
# 1636    Audi A1   Compact     23090  VAT deductible  9821.0     NaN  Used
#
#       previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 1636              1.0            Yes   Metallic          2.0          3.0
#
#      gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 1636    Automatic            1798.0        4.0      1240.0       front
#
#          fuel  co2_emission(g/km) emission_class  \
# 1636  Benzine               134.0         Euro 6
#
#                                 comfort_and_convenience  \
# 1636  Air conditioning,Armrest,Automatic climate con...
#
#                                entertaintment_and_media  \
# 1636  Bluetooth,CD player,Digital radio,Hands-free e...
#
#                                                  extras  \
# 1636  Alloy wheels,Catalytic Converter,Sport package...
#
#                                     safety_and_security  gears  age  \
# 1636  ABS,Central door lock,Daytime running lights,D...    7.0  1.0
#
#      upholstery_style upholstery_color  consumption_comb(100km/l)
# 1636     Part leather            Black                        5.8

# %%
df.loc[(df["make_model"] == "Audi A1") & (df["body_type"] == "Compact")]["num_of_seat"].value_counts()
# Out:
# 5.0    579
# 4.0    457
# 6.0      1
# 3.0      1
# Name: num_of_seat, dtype: int64

# %%
df.loc[df["num_of_seat"]==6]
# Out:
#            make_model      body_type  price(€)             vat         km  \
# 582           Audi A1        Compact     13500  VAT deductible  100000.00
# 15890  Renault Espace  Station wagon     42490  VAT deductible   77442.52
#
#        hp(kw)  type  previous_owners inspection_new paint_type  num_of_door  \
# 582      70.0  Used              1.0             No   Metallic          5.0
# 15890   147.0   New              1.0             No   Metallic          5.0
#
#        num_of_seat gearing_type  displacement(cc)  cylinders  weight(kg)  \
# 582            6.0       Manual            1000.0        4.0      1500.0
# 15890          6.0    Automatic            1997.0        4.0      1840.0
#
#       drive_chain     fuel  co2_emission(g/km) emission_class  \
# 582         front  Benzine               123.0         Euro 6
# 15890       front   Diesel               168.0         Euro 6
#
#                                  comfort_and_convenience  \
# 582                                     Air conditioning
# 15890  Air conditioning,Armrest,Automatic climate con...
#
#                                 entertaintment_and_media  \
# 582                                    On-board computer
# 15890  Bluetooth,Hands-free equipment,On-board comput...
#
#                           extras  \
# 582                 Alloy wheels
# 15890  Alloy wheels,Touch screen
#
#                                      safety_and_security  gears  age  \
# 582                                                  ABS    5.0  2.0
# 15890  ABS,Blind spot monitor,Central door lock,Dayti...    6.0  0.0
#
#       upholstery_style upholstery_color  consumption_comb(100km/l)
# 582              Cloth            Black                        4.7
# 15890            Cloth            Other                        5.7

# %%
df.loc[(df["num_of_seat"]==6) | (df["num_of_seat"]==3), "num_of_seat"] = np.nan

# %%
df["num_of_seat"].value_counts(dropna=False)
# Out:
# 5.0    14175
# 4.0     1194
# 7.0      409
# 2.0      131
# NaN        3
# Name: num_of_seat, dtype: int64

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        condition = (df["make_model"] == makemodel) & (df["body_type"] == bodytype)
        df.loc[condition, "num_of_seat"] = df.loc[condition, "num_of_seat"].fillna(method="ffill").fillna(method="bfill")

df["num_of_seat"] = df["num_of_seat"].fillna(method="ffill").fillna(method="bfill")

# %%
df["num_of_seat"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 7- displacement(cc) column

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# cylinders, weight, horsepower
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="displacement(cc)");

# %% [markdown]
# ##### Opel Astra

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Astra"]["displacement(cc)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1896.5, 1100.5)

# %%
condition = (df["make_model"]=="Opel Astra") & (df["displacement(cc)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].sort_values(by="displacement(cc)")[:6]
# Out:
#       make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 7809  Opel Astra         Sedans        4.0      1352.0   110.0
# 7810  Opel Astra         Sedans        4.0      1352.0   110.0
# 7811  Opel Astra         Sedans        4.0      1352.0   110.0
# 7812  Opel Astra         Sedans        4.0      1352.0   110.0
# 8128  Opel Astra  Station wagon        3.0      1403.0    92.0
# 5869  Opel Astra         Sedans        3.0      1410.0    77.0
#
#       displacement(cc)
# 7809             139.0
# 7810             139.0
# 7811             139.0
# 7812             139.0
# 8128             140.0
# 5869             996.0

# %%
df.loc[(df["make_model"]=="Opel Astra") & (df["displacement(cc)"] < 150), "displacement(cc)"] = np.nan

# %%
condition = (df["make_model"]=="Opel Astra") & (df["displacement(cc)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].sort_values(by="displacement(cc)")
# Out:
#       make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 7169  Opel Astra  Station wagon        4.0      1388.0   100.0
#
#       displacement(cc)
# 7169           15898.0

# %%
df.loc[df.index == 7169, "displacement(cc)"] = np.nan

# %% [markdown]
# ##### Opel Corsa

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Corsa"]["displacement(cc)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1651.5, 975.5)

# %%
condition = (df["make_model"]=="Opel Corsa") & (df["displacement(cc)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
#        make_model body_type  cylinders  weight(kg)  hp(kw)  displacement(cc)
# 10194  Opel Corsa   Compact        4.0      1162.0    51.0             122.0
# 8857   Opel Corsa   Compact        4.0       840.0    40.0             973.0

# %%
df.loc[(df["make_model"]=="Opel Corsa") & (df["displacement(cc)"] < 130), "displacement(cc)"] = np.nan

# %% [markdown]
# ##### Opel Insignia

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Insignia"]["displacement(cc)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (2655.0, 791.0)

# %%
condition = (df["make_model"]=="Opel Insignia") & (df["displacement(cc)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
#           make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 12769  Opel Insignia        Compact        4.0      1441.0   147.0
# 12835  Opel Insignia         Sedans        4.0      1341.0   147.0
# 12823  Opel Insignia  Station wagon        4.0      1865.0   121.0
# 12815  Opel Insignia  Station wagon        4.0      1540.0   100.0
# 12800  Opel Insignia  Station wagon        4.0      1522.0   125.0
# 12798  Opel Insignia  Station wagon        4.0      1522.0   100.0
# 12796  Opel Insignia         Sedans        4.0      1503.0   147.0
# 12790  Opel Insignia  Station wagon        4.0      1560.0   100.0
# 12786  Opel Insignia  Station wagon        4.0      1387.0   100.0
# 12783  Opel Insignia        Compact        4.0      1441.0   147.0
# 12781  Opel Insignia  Station wagon        4.0      1387.0   147.0
# 12849  Opel Insignia  Station wagon        4.0      1485.0   100.0
# 12768  Opel Insignia  Station wagon        4.0      1403.0   100.0
# 12750  Opel Insignia         Sedans        4.0      1483.0   147.0
# 12670  Opel Insignia  Station wagon        4.0      1552.0   100.0
# 12604  Opel Insignia  Station wagon        4.0      1487.0   100.0
# 12554  Opel Insignia  Station wagon        4.0      1613.0   121.0
# 12501  Opel Insignia  Station wagon        4.0      1772.0   100.0
# 12499  Opel Insignia  Station wagon        4.0      1772.0   100.0
# 12484  Opel Insignia         Sedans        4.0      1618.0   100.0
# 12473  Opel Insignia  Station wagon        4.0      1582.0   100.0
# 12467  Opel Insignia  Station wagon        4.0      1552.0   100.0
# 12848  Opel Insignia  Station wagon        4.0      1485.0   100.0
# 10559  Opel Insignia  Station wagon        4.0      1929.0   125.0
#
#        displacement(cc)
# 12769               1.0
# 12835               1.0
# 12823               1.0
# 12815               1.0
# 12800               1.0
# 12798               1.0
# 12796               1.0
# 12790               1.0
# 12786               1.0
# 12783               1.0
# 12781               1.0
# 12849               1.0
# 12768               1.0
# 12750               1.0
# 12670               1.0
# 12604               1.0
# 12554               1.0
# 12501               1.0
# 12499               1.0
# 12484               1.0
# 12473               1.0
# 12467               1.0
# 12848               1.0
# 10559               2.0

# %%
df.loc[condition, "displacement(cc)"] = np.nan

# %%
condition = (df["make_model"]=="Opel Insignia") & (df["displacement(cc)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
#           make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 10771  Opel Insignia  Station wagon        6.0      2295.0   100.0
# 10932  Opel Insignia  Station wagon        4.0      1733.0    88.0
#
#        displacement(cc)
# 10771            2967.0
# 10932           16000.0

# %%
df.loc[(df["make_model"]=="Opel Insignia") & (df["displacement(cc)"] > 15000), "displacement(cc)"] = np.nan

# %% [markdown]
# ##### Renault Clio

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Clio"]["displacement(cc)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1929.0, 681.0)

# %%
condition = (df["make_model"]=="Renault Clio") & (df["displacement(cc)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
#          make_model body_type  cylinders  weight(kg)  hp(kw)  displacement(cc)
# 13904  Renault Clio    Sedans        4.0      1052.0    54.0               1.0
# 14284  Renault Clio    Sedans        4.0      1134.0    54.0               1.0
# 14314  Renault Clio    Sedans        4.0       900.0    54.0               1.0
# 14315  Renault Clio    Sedans        4.0       900.0    54.0               1.0
# 14319  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14320  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14321  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14322  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14324  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14325  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14326  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14327  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14328  Renault Clio    Sedans        4.0      1165.0    54.0               1.0
# 14198  Renault Clio    Sedans        4.0      1071.0    66.0               2.0
# 13912  Renault Clio    Sedans        4.0      1134.0    54.0              54.0

# %%
df.loc[condition, "displacement(cc)"] = np.nan

# %%
condition = (df["make_model"]=="Renault Clio") & (df["displacement(cc)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, cylinders, weight(kg), hp(kw), displacement(cc)]
# Index: []

# %% [markdown]
# ##### Renault Espace

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Espace"]["displacement(cc)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (2098.0, 1298.0)

# %%
condition = (df["make_model"]=="Renault Espace") & (df["displacement(cc)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
#            make_model body_type  cylinders  weight(kg)  hp(kw)  \
# 15574  Renault Espace       Van        4.0      1659.0   118.0
# 15575  Renault Espace       Van        4.0      1659.0   118.0
# 15576  Renault Espace       Van        4.0      1659.0   118.0
# 15577  Renault Espace       Van        4.0      1659.0   118.0
# 15578  Renault Espace       Van        4.0      1659.0   118.0
# 15579  Renault Espace       Van        4.0      1659.0   118.0
#
#        displacement(cc)
# 15574             160.0
# 15575             160.0
# 15576             160.0
# 15577             160.0
# 15578             160.0
# 15579             160.0

# %%
df.loc[condition, "displacement(cc)"] = np.nan

# %%
condition = (df["make_model"]=="Renault Espace") & (df["displacement(cc)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="displacement(cc)")
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, cylinders, weight(kg), hp(kw), displacement(cc)]
# Index: []

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="displacement(cc)");

# %% [markdown]
# ### 8- cylinders column

# %%
df["cylinders"].describe()
# Out:
# count    15912.000000
# mean         3.782868
# std          0.422842
# min          1.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          8.000000
# Name: cylinders, dtype: float64

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# displacement, weight, horsepower
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="cylinders");

# %% [markdown]
# ##### Audi A1

# %%
df.loc[df["make_model"] == "Audi A1", "cylinders"].value_counts()
# Out:
# 3.0    2031
# 4.0     581
# 8.0       1
# Name: cylinders, dtype: int64

# %%
condition = (df["make_model"] == "Audi A1") & (df["cylinders"] >= 4) & (df["body_type"] == "Compact")
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="cylinders")
# Out:
#      make_model body_type  cylinders  weight(kg)  hp(kw)  displacement(cc)
# 40      Audi A1   Compact        4.0      1110.0    60.0             999.0
# 1102    Audi A1   Compact        4.0      1215.0    92.0            1395.0
# 1131    Audi A1   Compact        4.0      1200.0    85.0            1598.0
# 1133    Audi A1   Compact        4.0      1200.0    85.0            1598.0
# 1137    Audi A1   Compact        4.0      1200.0    85.0            1598.0
# ...         ...       ...        ...         ...     ...               ...
# 408     Audi A1   Compact        4.0      1205.0   110.0            1395.0
# 410     Audi A1   Compact        4.0      1205.0    66.0            1422.0
# 375     Audi A1   Compact        4.0      1792.0    66.0            1422.0
# 2393    Audi A1   Compact        4.0      1335.0    70.0             999.0
# 535     Audi A1   Compact        8.0      1285.0    70.0             999.0
#
# [219 rows x 6 columns]

# %%
condition = (df["make_model"] == "Audi A1") & (df["cylinders"] == 8)
df[condition]
# Out:
#     make_model body_type  price(€)             vat       km  hp(kw)  type  \
# 535    Audi A1   Compact     12990  VAT deductible  41200.0    70.0  Used
#
#      previous_owners inspection_new paint_type  num_of_door  num_of_seat  \
# 535              1.0            Yes   Metallic          5.0          4.0
#
#     gearing_type  displacement(cc)  cylinders  weight(kg) drive_chain  \
# 535       Manual             999.0        8.0      1285.0       front
#
#         fuel  co2_emission(g/km) emission_class  \
# 535  Benzine               331.0         Euro 4
#
#                                comfort_and_convenience  \
# 535  Air conditioning,Automatic climate control,Ele...
#
#                               entertaintment_and_media  \
# 535  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                        extras  \
# 535  Ski bag,Sport suspension
#
#                                    safety_and_security  gears  age  \
# 535  ABS,Alarm system,Central door lock,Driver-side...    5.0  3.0
#
#     upholstery_style upholstery_color  consumption_comb(100km/l)
# 535            Cloth            Black                       13.8

# %%
df.loc[df.index == 535, "cylinders"] = np.nan

# %% [markdown]
# ##### Audi A3

# %%
df.loc[df["make_model"] == "Audi A3", "cylinders"].value_counts()
# Out:
# 4.0    2472
# 3.0     602
# 5.0      21
# Name: cylinders, dtype: int64

# %%
condition = (df["make_model"] == "Audi A3") & (df["cylinders"] >= 4)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="cylinders").tail(50)
# Out:
#      make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 3458    Audi A3         Sedans        4.0      1355.0    81.0
# 3457    Audi A3         Sedans        4.0      1355.0    81.0
# 3456    Audi A3         Sedans        4.0      1355.0    81.0
# 3455    Audi A3         Sedans        4.0      1355.0    81.0
# 3461    Audi A3         Sedans        4.0      1360.0    85.0
# 3453    Audi A3         Sedans        4.0      1355.0    81.0
# 3452    Audi A3         Sedans        4.0      1355.0    81.0
# 3451    Audi A3         Sedans        4.0      1365.0    81.0
# 3450    Audi A3         Sedans        4.0      1360.0    81.0
# 3449    Audi A3         Sedans        4.0      1360.0    81.0
# 3448    Audi A3         Sedans        4.0      1360.0    81.0
# 3447    Audi A3         Sedans        4.0      1395.0   110.0
# 3446    Audi A3         Sedans        4.0      1355.0    81.0
# 3462    Audi A3         Sedans        4.0      1360.0    81.0
# 3463    Audi A3         Sedans        4.0      1360.0    81.0
# 3464    Audi A3         Sedans        4.0      1360.0    81.0
# 3465    Audi A3         Sedans        4.0      1400.0   110.0
# 3466    Audi A3         Sedans        4.0      1355.0    81.0
# 3467    Audi A3         Sedans        4.0      1355.0    81.0
# 3468    Audi A3         Sedans        4.0      1360.0    81.0
# 3469    Audi A3         Sedans        4.0      1400.0   110.0
# 3470    Audi A3         Sedans        4.0      1355.0    81.0
# 3471    Audi A3         Sedans        4.0      1360.0    81.0
# 3472    Audi A3         Sedans        4.0      1360.0    81.0
# 3473    Audi A3         Sedans        4.0      1400.0   110.0
# 3474    Audi A3         Sedans        4.0      1365.0    81.0
# 3475    Audi A3         Sedans        4.0      1360.0    81.0
# 3459    Audi A3         Sedans        4.0      1365.0    81.0
# 3460    Audi A3         Sedans        4.0      1355.0    81.0
# 4185    Audi A3  Station wagon        5.0      1180.0    85.0
# 3649    Audi A3        Compact        5.0      1485.0   294.0
# 3603    Audi A3         Sedans        5.0      1585.0   294.0
# 3610    Audi A3         Sedans        5.0      1585.0   294.0
# 3602    Audi A3         Sedans        5.0      1585.0   294.0
# 3601    Audi A3         Sedans        5.0      1585.0   294.0
# 3600    Audi A3         Sedans        5.0      1590.0   294.0
# 3599    Audi A3         Sedans        5.0      1590.0   294.0
# 3605    Audi A3         Sedans        5.0      1585.0   294.0
# 3606    Audi A3         Sedans        5.0      1585.0   294.0
# 3596    Audi A3         Sedans        5.0      1585.0   294.0
# 3595    Audi A3  Station wagon        5.0      1585.0   294.0
# 3594    Audi A3         Sedans        5.0      1585.0   228.0
# 3593    Audi A3         Sedans        5.0      1585.0   294.0
# 3592    Audi A3         Sedans        5.0      1585.0   294.0
# 3590    Audi A3         Sedans        5.0      1585.0   294.0
# 3608    Audi A3         Sedans        5.0      1595.0   270.0
# 3587    Audi A3         Sedans        5.0      1585.0   294.0
# 3609    Audi A3         Sedans        5.0      1595.0   270.0
# 3604    Audi A3         Sedans        5.0      1585.0   294.0
# 3598    Audi A3         Sedans        5.0      1585.0   294.0
#
#       displacement(cc)
# 3458            1598.0
# 3457            1395.0
# 3456            1598.0
# 3455            1598.0
# 3461            1598.0
# 3453            1598.0
# 3452            1598.0
# 3451            1598.0
# 3450            1598.0
# 3449            1598.0
# 3448            1598.0
# 3447            1968.0
# 3446            1598.0
# 3462            1598.0
# 3463            1598.0
# 3464            1598.0
# 3465            1968.0
# 3466            1598.0
# 3467            1598.0
# 3468            1598.0
# 3469            1968.0
# 3470            1598.0
# 3471            1598.0
# 3472            1598.0
# 3473            1968.0
# 3474            1598.0
# 3475            1598.0
# 3459            1598.0
# 3460            1598.0
# 4185            1598.0
# 3649            2480.0
# 3603            2480.0
# 3610            2480.0
# 3602            2480.0
# 3601            2480.0
# 3600            2480.0
# 3599            2480.0
# 3605            2480.0
# 3606            2480.0
# 3596            2480.0
# 3595            2480.0
# 3594            1984.0
# 3593            2480.0
# 3592            2480.0
# 3590            2480.0
# 3608            2480.0
# 3587            2480.0
# 3609            2480.0
# 3604            2480.0
# 3598            2480.0

# %% [markdown]
# ##### Opel Astra

# %%
df.loc[df["make_model"] == "Opel Astra", "cylinders"].value_counts()
# Out:
# 4.0    2067
# 3.0     458
# Name: cylinders, dtype: int64

# %% [markdown]
# ##### Opel Corsa

# %%
df.loc[df["make_model"] == "Opel Corsa", "cylinders"].value_counts()
# Out:
# 4.0    2205
# 3.0      10
# 1.0       2
# Name: cylinders, dtype: int64

# %%
df.loc[df["cylinders"]== 1.0, "cylinders"] = np.nan

# %% [markdown]
# ##### Opel Insignia

# %%
df.loc[df["make_model"] == "Opel Insignia", "cylinders"].value_counts()
# Out:
# 4.0    2594
# 6.0       3
# 2.0       1
# Name: cylinders, dtype: int64

# %%
condition = (df["make_model"] == "Opel Insignia") & (df["cylinders"] >= 1)
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="cylinders").tail(10)
# Out:
#           make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 11322  Opel Insignia  Station wagon        4.0      1522.0   100.0
# 11323  Opel Insignia  Station wagon        4.0      1522.0   121.0
# 11324  Opel Insignia         Sedans        4.0      1522.0   125.0
# 11325  Opel Insignia  Station wagon        4.0      1701.0   125.0
# 11326  Opel Insignia         Sedans        4.0      1522.0   100.0
# 11319  Opel Insignia  Station wagon        4.0      1716.0   125.0
# 13054  Opel Insignia  Station wagon        4.0      1487.0   154.0
# 10771  Opel Insignia  Station wagon        6.0      2295.0   100.0
# 12897  Opel Insignia         Sedans        6.0      1487.0   100.0
# 10826  Opel Insignia  Station wagon        6.0      1701.0   100.0
#
#        displacement(cc)
# 11322            1598.0
# 11323            1490.0
# 11324            1998.0
# 11325            1598.0
# 11326            1598.0
# 11319            1956.0
# 13054            2000.0
# 10771            2967.0
# 12897            1600.0
# 10826            1598.0

# %%
df.loc[condition, ["make_model", "body_type", "cylinders", "weight(kg)", "hp(kw)", "displacement(cc)"]].\
sort_values(by="cylinders").head(10)
# Out:
#           make_model      body_type  cylinders  weight(kg)  hp(kw)  \
# 11342  Opel Insignia  Station wagon        2.0      1560.0   100.0
# 10457  Opel Insignia  Station wagon        4.0      1613.0   100.0
# 12184  Opel Insignia  Station wagon        4.0      1487.0   121.0
# 12185  Opel Insignia         Sedans        4.0      1472.0   103.0
# 12186  Opel Insignia  Station wagon        4.0      1487.0   121.0
# 12187  Opel Insignia         Sedans        4.0      1472.0   103.0
# 12188  Opel Insignia  Station wagon        4.0      1487.0   121.0
# 12189  Opel Insignia  Station wagon        4.0      1633.0   125.0
# 12190  Opel Insignia  Station wagon        4.0      1487.0   103.0
# 12191  Opel Insignia  Station wagon        4.0      1537.0   100.0
#
#        displacement(cc)
# 11342            1598.0
# 10457            1598.0
# 12184            1490.0
# 12185            1490.0
# 12186            1490.0
# 12187            1500.0
# 12188            1490.0
# 12189            1956.0
# 12190            1490.0
# 12191            1598.0

# %%
condition = (df["make_model"] == "Opel Insignia") & ((df["cylinders"] == 2) | (df["cylinders"] == 6))

# %%
df.loc[condition, "cylinders"]  = np.nan

# %% [markdown]
# ##### Renault Clio

# %%
df.loc[df["make_model"] == "Renault Clio", "cylinders"].value_counts()
# Out:
# 4.0    1456
# 3.0     382
# 5.0       1
# Name: cylinders, dtype: int64

# %%
df.loc[(df["make_model"] == "Renault Clio") & (df["cylinders"]== 5), "cylinders"] = np.nan

# %% [markdown]
# ##### Renault Duster

# %%
df.loc[df["make_model"] == "Renault Duster", "cylinders"].value_counts()
# Out:
# 4.0    34
# Name: cylinders, dtype: int64

# %% [markdown]
# ##### Renault Espace

# %%
df.loc[df["make_model"] == "Renault Espace", "cylinders"].value_counts()
# Out:
# 4.0    987
# 8.0      2
# 2.0      2
# Name: cylinders, dtype: int64

# %%
df.loc[(df["make_model"] == "Renault Espace") & ((df["cylinders"]== 2) | (df["cylinders"] == 8)), "cylinders"] = np.nan

# %%
df.groupby("make_model")["cylinders"].value_counts()
# Out:
# make_model      cylinders
# Audi A1         3.0          2031
#                 4.0           581
# Audi A3         4.0          2472
#                 3.0           602
#                 5.0            21
# Opel Astra      4.0          2067
#                 3.0           458
# Opel Corsa      4.0          2205
#                 3.0            10
# Opel Insignia   4.0          2594
# Renault Clio    4.0          1456
#                 3.0           382
# Renault Duster  4.0            34
# Renault Espace  4.0           987
# Name: cylinders, dtype: int64

# %% [markdown]
# ### 9- weight(kg) column

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# hp(kw), displacement(cc), gears, price
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="weight(kg)");

# %% [markdown]
# ##### Audi A1

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Audi A1"]["weight(kg)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1397.5, 977.5)

# %%
condition = (df["make_model"]=="Audi A1") & (df["weight(kg)"] < lower_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]]
# Out:
#       weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 1143       102.0    70.0             999.0    7.0     19229

# %%
df.loc[condition, "weight(kg)"] = np.nan

# %%
condition = (df["make_model"]=="Audi A1") & (df["weight(kg)"] > upper_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values("weight(kg)").tail(20)
# Out:
#      weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 343      1792.0    66.0            1422.0    7.0     14990
# 344      1792.0    66.0            1422.0    7.0     14990
# 345      1792.0    66.0            1422.0    7.0     14990
# 346      1792.0    66.0            1422.0    7.0     14990
# 349      1792.0    66.0            1422.0    7.0     14990
# 371      1792.0    85.0            1598.0    7.0     14890
# 351      1792.0    66.0            1422.0    7.0     14990
# 356      1792.0    66.0            1422.0    7.0     14990
# 357      1792.0    66.0            1422.0    7.0     14990
# 358      1792.0    66.0            1422.0    7.0     14990
# 359      1792.0    66.0            1422.0    7.0     14990
# 328      1792.0    85.0            1598.0    7.0     14998
# 360      1792.0    66.0            1422.0    7.0     14990
# 362      1792.0    66.0            1422.0    7.0     14990
# 323      1792.0    70.0             999.0    7.0     14990
# 308      1792.0    85.0            1598.0    7.0     13990
# 330      1792.0    70.0             999.0    7.0     14990
# 365      1792.0    92.0            1395.0    7.0     14930
# 352      1792.0    66.0            1422.0    7.0     14990
# 364      1792.0    70.0             999.0    7.0     14959

# %% [markdown]
# ##### Opel Corsa

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Corsa"]["weight(kg)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1259.0, 1099.0)

# %%
condition = (df["make_model"]=="Opel Corsa") & (df["weight(kg)"] < lower_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values(by="weight(kg)").head(10)
# Out:
#       weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 8356         1.0    66.0            1398.0    5.0     12945
# 8355         1.0    66.0            1398.0    5.0     12945
# 8858       840.0    51.0            1229.0    5.0      7650
# 8859       840.0    51.0            1229.0    5.0      7650
# 8861       840.0    66.0            1398.0    5.0      7800
# 8863       840.0    51.0            1229.0    5.0      7950
# 8857       840.0    40.0             973.0    5.0      7650
# 8399      1041.0    66.0            1398.0    5.0     12750
# 8397      1041.0    66.0            1398.0    5.0     12750
# 8292      1041.0    66.0            1398.0    6.0     13600

# %%
condition = (df["make_model"]=="Opel Corsa") & (df["weight(kg)"] < 10)
df.loc[condition, "weight(kg)"] = np.nan

# %%
condition = (df["make_model"]=="Opel Corsa") & (df["weight(kg)"] > upper_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values("weight(kg)").tail(10)
# Out:
#       weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 8691      1665.0    51.0            1229.0    5.0      7450
# 8690      1665.0    51.0            1229.0    5.0      7480
# 8689      1665.0    55.0            1248.0    5.0      7495
# 8657      1665.0    55.0            1248.0    5.0      7495
# 8637      1665.0    55.0            1248.0    5.0      7495
# 8752      1695.0    55.0            1248.0    5.0      6950
# 8686      1695.0    70.0            1248.0    6.0      7450
# 9454      1695.0    55.0            1248.0    5.0      8900
# 8923      1695.0    70.0            1248.0    6.0      7950
# 9686      1960.0    66.0            1398.0    6.0     14477

# %% [markdown]
# ##### Opel Insignia

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Opel Insignia"]["weight(kg)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1910.5, 1258.5)

# %%
condition = (df["make_model"]=="Opel Insignia") & (df["weight(kg)"] < lower_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values(by="weight(kg)").head(10)
# Out:
#        weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 12779         1.0   121.0            1500.0    6.0     39299
# 12142      1124.0   121.0            1496.0    6.0     20980
# 11620      1252.0    81.0            1229.0    5.0     17094

# %%
df.loc[df.index==12779, "weight(kg)"] = np.nan

# %%
condition = (df["make_model"]=="Opel Insignia") & (df["weight(kg)"] > upper_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values("weight(kg)").tail(10)
# Out:
#        weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 11752      2355.0   103.0            1490.0    6.0     16400
# 11750      2355.0   103.0            1364.0    6.0     16900
# 10882      2400.0   100.0            1598.0    6.0     12675
# 11077      2400.0   100.0            1598.0    6.0     12650
# 11078      2400.0   100.0            1598.0    6.0     12595
# 10881      2400.0    88.0            1598.0    6.0     11500
# 10646      2450.0   125.0            1956.0    6.0     14500
# 10642      2450.0   100.0            1598.0    6.0     14800
# 10639      2450.0   100.0            1598.0    6.0     14850
# 10638      2450.0   125.0            1956.0    6.0     14900

# %% [markdown]
# ##### Renault Espace

# %%
q3, q1 = np.percentile(df[df["make_model"] == "Renault Espace"]["weight(kg)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1846.5, 1546.5)

# %%
condition = (df["make_model"]=="Renault Espace") & (df["weight(kg)"] < lower_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values(by="weight(kg)").head(10)
# Out:
#        weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 15008      1252.0   118.0            1618.0    6.0     26994
# 15785      1252.0   165.0            1618.0    6.0     34140
# 15324      1515.0    96.0            1598.0    6.0     24950
# 15370      1515.0    96.0            1598.0    6.0     18950
# 15311      1540.0    96.0            1598.0    6.0     17750
# 15322      1540.0    96.0            1598.0    6.0     24800
# 15325      1540.0    96.0            1598.0    6.0     23900
# 15326      1540.0    96.0            1598.0    6.0     24900
# 15329      1540.0    96.0            1598.0    6.0     22300
# 15385      1540.0   118.0            1598.0    6.0     23900

# %%
condition = (df["make_model"]=="Renault Espace") & (df["weight(kg)"] > upper_bound)
df.loc[condition, ["weight(kg)", "hp(kw)", "displacement(cc)", "gears", "price(€)"]].sort_values("weight(kg)").tail(10)
# Out:
#        weight(kg)  hp(kw)  displacement(cc)  gears  price(€)
# 15133      2410.0   147.0            1618.0    7.0     24400
# 15143      2410.0   147.0            1618.0    7.0     23990
# 15170      2410.0   147.0            1618.0    7.0     21950
# 15136      2410.0   147.0            1618.0    7.0     24400
# 15678      2471.0   118.0            1598.0    6.0     38990
# 14975      2471.0   118.0            1598.0    6.0     25500
# 15185      2471.0   118.0            1598.0    6.0     20900
# 15186      2471.0   117.0            1598.0    6.0     20900
# 15231      2471.0   118.0            1598.0    6.0     20900
# 15280      2471.0   118.0            1598.0    6.0     17400

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="make_model", y="weight(kg)");

# %% [markdown]
# ### 10- co2_emission(g/km) column

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price(€)', 'vat', 'km', 'hp(kw)', 'type',
#        'previous_owners', 'inspection_new', 'paint_type', 'num_of_door',
#        'num_of_seat', 'gearing_type', 'displacement(cc)', 'cylinders',
#        'weight(kg)', 'drive_chain', 'fuel', 'co2_emission(g/km)',
#        'emission_class', 'comfort_and_convenience', 'entertaintment_and_media',
#        'extras', 'safety_and_security', 'gears', 'age', 'upholstery_style',
#        'upholstery_color', 'consumption_comb(100km/l)'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
df.groupby("fuel")["co2_emission(g/km)"].describe()
# Out:
#            count        mean         std   min    25%    50%     75%      max
# fuel
# Benzine   8547.0  132.341055  338.160686   0.0  113.0  123.0  130.00  14457.0
# Diesel    7296.0  110.500548   22.470409   0.0  101.0  106.0  118.00   1060.0
# Electric     5.0   36.000000    0.000000  36.0   36.0   36.0   36.00     36.0
# LPG/CNG     64.0  101.250000   10.668155  91.0   94.0   97.0  110.75    135.0

# %%
df.groupby("emission_class")["co2_emission(g/km)"].describe()
# Out:
#                   count        mean         std   min     25%    50%    75%  \
# emission_class
# Euro 4             46.0  167.000000   43.695410   1.0  150.00  186.0  186.0
# Euro 5            100.0  113.390000   18.933107  85.0   97.75  106.0  123.0
# Euro 6          15766.0  122.096283  249.664478   0.0  106.00  116.0  126.0
#
#                     max
# emission_class
# Euro 4            331.0
# Euro 5            175.0
# Euro 6          14457.0

# %%
sns.boxplot(data=df, x="fuel", y="co2_emission(g/km)", hue="emission_class")
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='co2_emission(g/km)'>

# %%
sns.boxplot(data=df, y="co2_emission(g/km)", x="emission_class")
# Out:
# <AxesSubplot:xlabel='emission_class', ylabel='co2_emission(g/km)'>

# %% [markdown]
# ##### Euro 6

# %%
q3, q1 = np.percentile(df[df["emission_class"] == "Euro 6"]["co2_emission(g/km)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (156.0, 76.0)

# %%
condition = (df["emission_class"]=="Euro 6") & (df["co2_emission(g/km)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#           make_model      body_type  hp(kw)      fuel  co2_emission(g/km)
# 8217      Opel Astra         Sedans    92.0   Benzine                 0.0
# 10566  Opel Insignia  Station wagon   125.0    Diesel                 0.0
# 6397      Opel Astra         Sedans    81.0    Diesel                 5.0
# 11553  Opel Insignia  Station wagon   125.0    Diesel                 5.0
# 13008  Opel Insignia          Other   100.0    Diesel                 5.0
# 8110      Opel Astra  Station wagon    77.0   Benzine                14.0
# 3356         Audi A3        Compact   150.0  Electric                36.0
# 3612         Audi A3         Sedans   110.0  Electric                36.0
# 3615         Audi A3         Sedans   110.0  Electric                36.0
# 3617         Audi A3         Sedans   110.0  Electric                36.0

# %%
condition = (df["emission_class"]=="Euro 6") & (df["co2_emission(g/km)"] < 36)
df.loc[condition, "co2_emission(g/km)"] = np.nan

# %%
condition = (df["emission_class"]=="Euro 6") & (df["co2_emission(g/km)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").tail(10)
# Out:
#           make_model      body_type  hp(kw)     fuel  co2_emission(g/km)
# 12054  Opel Insignia  Station wagon   125.0   Diesel               199.0
# 10513  Opel Insignia  Station wagon     NaN  Benzine               253.0
# 4556         Audi A3         Sedans    81.0   Diesel               990.0
# 4089         Audi A3         Sedans    85.0   Diesel              1060.0
# 6578      Opel Astra  Station wagon   110.0  Benzine             12087.0
# 6579      Opel Astra  Station wagon   110.0  Benzine             12087.0
# 5818      Opel Astra         Sedans   110.0  Benzine             12087.0
# 8542      Opel Corsa        Compact    66.0  Benzine             12324.0
# 12343  Opel Insignia         Sedans   103.0  Benzine             13983.0
# 11888  Opel Insignia  Station wagon   121.0  Benzine             14457.0

# %%
condition = (df["emission_class"]=="Euro 6") & (df["co2_emission(g/km)"] > 900)
df.loc[condition, "co2_emission(g/km)"] = np.nan

# %% [markdown]
# ##### Euro 5

# %%
q3, q1 = np.percentile(df[df["emission_class"] == "Euro 5"]["co2_emission(g/km)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (160.875, 59.875)

# %%
condition = (df["emission_class"]=="Euro 5") & (df["co2_emission(g/km)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, hp(kw), fuel, co2_emission(g/km)]
# Index: []

# %%
condition = (df["emission_class"]=="Euro 5") & (df["co2_emission(g/km)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").tail(10)
# Out:
#           make_model      body_type  hp(kw)     fuel  co2_emission(g/km)
# 5997      Opel Astra         Sedans    85.0  Benzine               167.0
# 10690  Opel Insignia  Station wagon   143.0   Diesel               169.0
# 11446  Opel Insignia  Station wagon   125.0  Benzine               170.0
# 10539  Opel Insignia  Station wagon   143.0   Diesel               175.0

# %% [markdown]
# ##### Euro 4

# %%
q3, q1 = np.percentile(df[df["emission_class"] == "Euro 4"]["co2_emission(g/km)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (240.0, 96.0)

# %%
condition = (df["emission_class"]=="Euro 4") & (df["co2_emission(g/km)"] < lower_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#            make_model body_type  hp(kw)     fuel  co2_emission(g/km)
# 14902  Renault Duster  Off-Road    77.0  Benzine                 1.0

# %%
df.loc[df.index == 14902, "co2_emission(g/km)"] = np.nan

# %%
condition = (df["emission_class"]=="Euro 4") & (df["co2_emission(g/km)"] > upper_bound)
df.loc[condition, ["make_model", "body_type", "hp(kw)", "fuel", "co2_emission(g/km)"]].sort_values(by="co2_emission(g/km)").tail(10)
# Out:
#     make_model body_type  hp(kw)     fuel  co2_emission(g/km)
# 535    Audi A1   Compact    70.0  Benzine               331.0

# %%
df.loc[df.index == 535, "co2_emission(g/km)"] = np.nan

# %%
sns.boxplot(data=df, x="emission_class", y="co2_emission(g/km)")
# Out:
# <AxesSubplot:xlabel='emission_class', ylabel='co2_emission(g/km)'>

# %% [markdown]
# ### 11- gears column

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# hp(kw), weight(kg)
# Out:
# <AxesSubplot:>

# %%
df.groupby(["make_model","gearing_type"])["gears"].value_counts()
# Out:
# make_model      gearing_type    gears
# Audi A1         Automatic       7.0      1065
#                                 6.0        44
#                                 5.0        37
#                                 8.0         6
#                 Manual          5.0      1160
#                                 6.0       222
#                                 7.0        22
#                 Semi-automatic  7.0        56
#                                 6.0         1
# Audi A3         Automatic       7.0      1231
#                                 6.0       129
#                 Manual          6.0      1455
#                                 7.0        17
#                                 5.0         4
#                 Semi-automatic  7.0       210
#                                 6.0        49
# Opel Astra      Automatic       6.0      1001
#                                 5.0        89
#                                 7.0         3
#                 Manual          6.0      1003
#                                 5.0       411
#                 Semi-automatic  5.0        10
#                                 6.0         8
# Opel Corsa      Automatic       6.0       655
#                                 5.0       214
#                                 8.0         1
#                 Manual          5.0      1243
#                                 6.0        53
#                                 2.0         1
#                 Semi-automatic  5.0        43
#                                 6.0         6
#                                 1.0         1
# Opel Insignia   Automatic       6.0      1034
#                                 8.0       279
#                                 5.0         9
#                                 7.0         2
#                 Manual          6.0      1269
#                                 8.0         3
#                                 5.0         2
# Renault Clio    Automatic       6.0       578
#                                 5.0        37
#                                 7.0         4
#                                 1.0         1
#                 Manual          5.0      1136
#                                 6.0        37
#                                 50.0        1
#                 Semi-automatic  6.0        45
# Renault Duster  Automatic       6.0         8
#                 Manual          6.0        26
# Renault Espace  Automatic       6.0       627
#                                 7.0       225
#                                 9.0        11
#                                 3.0         3
#                                 4.0         2
#                                 5.0         2
#                 Manual          6.0        76
#                                 7.0         6
#                 Semi-automatic  6.0        38
#                                 7.0         1
# Name: gears, dtype: int64

# %%
df.groupby(["make_model"])["gears"].value_counts()
# Out:
# make_model      gears
# Audi A1         5.0      1197
#                 7.0      1143
#                 6.0       267
#                 8.0         6
# Audi A3         6.0      1633
#                 7.0      1458
#                 5.0         4
# Opel Astra      6.0      2012
#                 5.0       510
#                 7.0         3
# Opel Corsa      5.0      1500
#                 6.0       714
#                 1.0         1
#                 2.0         1
#                 8.0         1
# Opel Insignia   6.0      2303
#                 8.0       282
#                 5.0        11
#                 7.0         2
# Renault Clio    5.0      1173
#                 6.0       660
#                 7.0         4
#                 1.0         1
#                 50.0        1
# Renault Duster  6.0        34
# Renault Espace  6.0       741
#                 7.0       232
#                 9.0        11
#                 3.0         3
#                 4.0         2
#                 5.0         2
# Name: gears, dtype: int64

# %%
df.groupby(["gearing_type"])["gears"].value_counts()
# Out:
# gearing_type    gears
# Automatic       6.0      4076
#                 7.0      2530
#                 5.0       388
#                 8.0       286
#                 9.0        11
#                 3.0         3
#                 4.0         2
#                 1.0         1
# Manual          6.0      4141
#                 5.0      3956
#                 7.0        45
#                 8.0         3
#                 2.0         1
#                 50.0        1
# Semi-automatic  7.0       267
#                 6.0       147
#                 5.0        53
#                 1.0         1
# Name: gears, dtype: int64

# %% [markdown]
# ##### Audi A1

# %%
condition = (df["make_model"] == "Audi A1") & (df["gears"] >= 7)
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears").tail(20)
# Out:
#       hp(kw)  weight(kg)    gearing_type  gears
# 773     66.0      1250.0  Semi-automatic    7.0
# 772     85.0      1275.0  Semi-automatic    7.0
# 771     70.0      1165.0  Semi-automatic    7.0
# 770     66.0      1220.0  Semi-automatic    7.0
# 769      NaN      1280.0  Semi-automatic    7.0
# 768     85.0      1195.0  Semi-automatic    7.0
# 741     85.0      1255.0  Semi-automatic    7.0
# 2527    70.0      1230.0          Manual    7.0
# 767     70.0      1195.0  Semi-automatic    7.0
# 766     66.0      1195.0  Semi-automatic    7.0
# 749     85.0      1275.0  Semi-automatic    7.0
# 745     66.0      1220.0  Semi-automatic    7.0
# 744      NaN      1205.0  Semi-automatic    7.0
# 743     85.0      1255.0  Semi-automatic    7.0
# 215     70.0      1165.0       Automatic    8.0
# 221     92.0      1195.0       Automatic    8.0
# 223     70.0      1195.0       Automatic    8.0
# 1033    60.0      1650.0       Automatic    8.0
# 218     66.0      1195.0       Automatic    8.0
# 217     92.0      1215.0       Automatic    8.0

# %%
condition = (df["make_model"] == "Audi A1") & (df["gears"] == 8)
df.loc[condition, "gears"] = np.nan

# %% [markdown]
# ##### Audi A3

# %%
condition = (df["make_model"] == "Audi A3") & (df["gears"] >= 5)
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears").head(10)
# Out:
#       hp(kw)  weight(kg) gearing_type  gears
# 4152    81.0      1260.0       Manual    5.0
# 3290    81.0      1260.0       Manual    5.0
# 3292   110.0      1455.0       Manual    5.0
# 3291    81.0      1260.0       Manual    5.0
# 4367    85.0      1335.0       Manual    6.0
# 4392    85.0      1260.0       Manual    6.0
# 4391    85.0      1260.0       Manual    6.0
# 4390    85.0      1180.0       Manual    6.0
# 4389    85.0      1335.0       Manual    6.0
# 4388   110.0      1335.0       Manual    6.0

# %%
condition = (df["make_model"] == "Audi A3") & (df["gears"] == 5)
df.loc[condition, "gears"] = np.nan

# %% [markdown]
# ##### Opel Astra

# %%
condition = (df["make_model"] == "Opel Astra") & (df["gears"] >= 6)
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears").tail(10)
# Out:
#       hp(kw)  weight(kg) gearing_type  gears
# 6485    81.0      1425.0       Manual    6.0
# 6486    70.0      1388.0       Manual    6.0
# 6487   100.0      1263.0       Manual    6.0
# 6488   118.0      1435.0       Manual    6.0
# 6489   100.0      1403.0       Manual    6.0
# 6492    81.0      1518.0       Manual    6.0
# 8236    92.0      1278.0       Manual    6.0
# 5860   100.0      1550.0    Automatic    7.0
# 5862   110.0      1550.0    Automatic    7.0
# 5863   100.0      1550.0    Automatic    7.0

# %% [markdown]
# ##### Opel Corsa

# %%
condition = (df["make_model"] == "Opel Corsa") & ((df["gears"] == 1) | (df["gears"] == 2) | (df["gears"] == 8))
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears")
# Out:
#        hp(kw)  weight(kg)    gearing_type  gears
# 8921     66.0      1163.0  Semi-automatic    1.0
# 9812     51.0      1141.0          Manual    2.0
# 10151    66.0      1163.0       Automatic    8.0

# %%
df.loc[condition, "gears"] = np.nan

# %% [markdown]
# ##### Opel Insignia

# %%
condition = (df["make_model"] == "Opel Insignia") & ((df["gears"] == 5) | (df["gears"] == 7))
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears").tail(20)
# Out:
#        hp(kw)  weight(kg) gearing_type  gears
# 10758   101.0      1623.0    Automatic    5.0
# 10759   101.0      1623.0    Automatic    5.0
# 10860   101.0      1513.0    Automatic    5.0
# 10866   100.0      1513.0    Automatic    5.0
# 10870   101.0      1513.0    Automatic    5.0
# 11499   100.0      1485.0    Automatic    5.0
# 11502   100.0      1664.0    Automatic    5.0
# 11505   125.0      1664.0    Automatic    5.0
# 11506   125.0      1664.0    Automatic    5.0
# 11620    81.0      1252.0       Manual    5.0
# 12735   121.0      1487.0       Manual    5.0
# 10811   100.0      1543.0    Automatic    7.0
# 10826   100.0      1701.0    Automatic    7.0

# %% [markdown]
# ##### Renault Clio

# %%
condition = (df["make_model"] == "Renault Clio") & ((df["gears"] == 50) | (df["gears"] == 7) | (df["gears"] == 1) | (df["gears"] == 6))
df.loc[condition, ["hp(kw)", "weight(kg)","gearing_type", "gears"]].sort_values(by="gears").tail(20)
# Out:
#        hp(kw)  weight(kg) gearing_type  gears
# 13272    87.0      1090.0    Automatic    6.0
# 13273    88.0      1079.0    Automatic    6.0
# 13274    87.0      1270.0    Automatic    6.0
# 13275    88.0      1079.0    Automatic    6.0
# 13286    87.0      1079.0    Automatic    6.0
# 13276    88.0      1079.0    Automatic    6.0
# 14879    66.0      1198.0       Manual    6.0
# 13278    88.0      1079.0    Automatic    6.0
# 13279    88.0      1079.0    Automatic    6.0
# 13280    88.0      1079.0    Automatic    6.0
# 13281    88.0      1079.0    Automatic    6.0
# 13282    88.0      1079.0    Automatic    6.0
# 13283    88.0      1079.0    Automatic    6.0
# 13284    88.0      1090.0    Automatic    6.0
# 13277    88.0      1079.0    Automatic    6.0
# 14089    67.0      1143.0    Automatic    7.0
# 14084    88.0      1143.0    Automatic    7.0
# 14354   163.0      1179.0    Automatic    7.0
# 14361    90.0      1233.0    Automatic    7.0
# 14495    56.0      1165.0       Manual   50.0

# %%
condition = (df["make_model"] == "Renault Clio") & ((df["gears"] == 50) | (df["gears"] == 1))
df.loc[condition, "gears"] = np.nan

# %% [markdown]
# ##### Renault Espace

# %%
condition = (df["make_model"] == "Renault Espace") & ((df["gears"] == 9) | (df["gears"] == 3))
df.loc[condition, "gears"] = np.nan

# %% [markdown]
# ### 12- age column

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
#km
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df, x="age", y="km")
# Out:
# <AxesSubplot:xlabel='age', ylabel='km'>

# %% [markdown]
# ### 13- consumption_comb(100km/l) column

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price(€)', 'vat', 'km', 'hp(kw)', 'type',
#        'previous_owners', 'inspection_new', 'paint_type', 'num_of_door',
#        'num_of_seat', 'gearing_type', 'displacement(cc)', 'cylinders',
#        'weight(kg)', 'drive_chain', 'fuel', 'co2_emission(g/km)',
#        'emission_class', 'comfort_and_convenience', 'entertaintment_and_media',
#        'extras', 'safety_and_security', 'gears', 'age', 'upholstery_style',
#        'upholstery_color', 'consumption_comb(100km/l)'],
#       dtype='object')

# %%
df.groupby("make_model")["consumption_comb(100km/l)"].describe()
# Out:
#                  count      mean       std  min   25%   50%   75%   max
# make_model
# Audi A1         2613.0  4.461672  2.037042  3.0   4.0   4.4   4.8  51.0
# Audi A3         3095.0  4.374637  1.395894  1.6   3.9   4.0   4.7  40.0
# Opel Astra      2525.0  4.704059  0.882923  0.0   3.9   4.6   5.4   7.5
# Opel Corsa      2217.0  5.450947  0.682092  3.0   5.2   5.4   5.9   7.8
# Opel Insignia   2598.0  5.384911  1.280792  0.0   4.9   5.5   5.9  55.0
# Renault Clio    1839.0  4.741762  2.072310  1.2   3.4   5.0   5.4  54.0
# Renault Duster    34.0  9.735294  1.543487  1.0  10.0  10.0  10.0  10.0
# Renault Espace   991.0  5.365489  1.636916  4.0   4.7   4.7   6.2  46.0

# %%
sns.barplot(data=df, x="fuel", y="consumption_comb(100km/l)")
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='consumption_comb(100km/l)'>

# %%
df.groupby("fuel")["consumption_comb(100km/l)"].describe()
# Out:
#            count      mean       std  min  25%  50%   75%   max
# fuel
# Benzine   8547.0  5.394987  1.494067  0.0  4.8  5.3  5.70  54.0
# Diesel    7296.0  4.263199  1.398302  0.0  3.8  4.0  4.60  55.0
# Electric     5.0  1.940000  0.760263  1.6  1.6  1.6  1.60   3.3
# LPG/CNG     64.0  4.589063  1.247997  3.3  3.4  5.1  5.45   8.3

# %%
sns.boxplot(data=df, x="fuel", y="consumption_comb(100km/l)")
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='consumption_comb(100km/l)'>

# %% [markdown]
# ##### Diesel

# %%
q3, q1 = np.percentile(df[df["fuel"] == "Diesel"]["consumption_comb(100km/l)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (5.799999999999999, 2.6)

# %%
condition = (df["fuel"]=="Diesel") & (df["consumption_comb(100km/l)"] < lower_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#           make_model  hp(kw)    fuel  co2_emission(g/km)  \
# 13678   Renault Clio    55.0  Diesel               106.0
# 10566  Opel Insignia   125.0  Diesel                 NaN
#
#        consumption_comb(100km/l)
# 13678                        1.2
# 10566                        0.0

# %%
df.loc[condition, "consumption_comb(100km/l)"] = np.nan

# %%
condition = (df["fuel"]=="Diesel") & (df["consumption_comb(100km/l)"] > upper_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#            make_model  hp(kw)    fuel  co2_emission(g/km)  \
# 14131    Renault Clio    66.0  Diesel                82.0
# 14530    Renault Clio    55.0  Diesel                85.0
# 2801          Audi A3    81.0  Diesel                99.0
# 4558          Audi A3    81.0  Diesel                99.0
# 6826       Opel Astra   100.0  Diesel               101.0
# 4102          Audi A3    85.0  Diesel               106.0
# 15232  Renault Espace   118.0  Diesel               106.0
# 15067  Renault Espace   118.0  Diesel               106.0
# 12908   Opel Insignia   125.0  Diesel               106.0
# 12647   Opel Insignia   125.0  Diesel               106.0
#
#        consumption_comb(100km/l)
# 14131                       32.0
# 14530                       33.0
# 2801                        10.0
# 4558                        38.0
# 6826                         6.0
# 4102                        40.0
# 15232                        6.2
# 15067                       46.0
# 12908                        6.0
# 12647                        6.0

# %%
condition = (df["fuel"]=="Diesel") & (df["consumption_comb(100km/l)"] > 30)
df.loc[condition, "consumption_comb(100km/l)"] = np.nan

# %% [markdown]
# ##### Benzine

# %%
q3, q1 = np.percentile(df[df["fuel"] == "Benzine"]["consumption_comb(100km/l)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (7.050000000000001, 3.4499999999999993)

# %%
condition = (df["fuel"]=="Benzine") & (df["consumption_comb(100km/l)"] < lower_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#            make_model  hp(kw)     fuel  co2_emission(g/km)  \
# 10322      Opel Corsa    51.0  Benzine               134.0
# 8217       Opel Astra    92.0  Benzine                 NaN
# 14902  Renault Duster    77.0  Benzine                 NaN
#
#        consumption_comb(100km/l)
# 10322                        3.0
# 8217                         0.0
# 14902                        1.0

# %%
df.loc[condition, "consumption_comb(100km/l)"] = np.nan

# %%
condition = (df["fuel"]=="Benzine") & (df["consumption_comb(100km/l)"] > upper_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#            make_model  hp(kw)     fuel  co2_emission(g/km)  \
# 500           Audi A1    70.0  Benzine                98.0
# 14584    Renault Clio    55.0  Benzine               114.0
# 2194          Audi A1    70.0  Benzine               116.0
# 2196          Audi A1    70.0  Benzine               116.0
# 2210          Audi A1    70.0  Benzine               116.0
# 2237          Audi A1    70.0  Benzine               116.0
# 13179    Renault Clio    88.0  Benzine               120.0
# 15684  Renault Espace   118.0  Benzine               123.0
# 15812  Renault Espace   165.0  Benzine               123.0
# 15814  Renault Espace   165.0  Benzine               123.0
#
#        consumption_comb(100km/l)
# 500                         43.0
# 14584                       50.0
# 2194                        51.0
# 2196                        51.0
# 2210                        51.0
# 2237                        51.0
# 13179                       54.0
# 15684                        7.4
# 15812                        7.6
# 15814                        7.6

# %%
condition = (df["fuel"]=="Benzine") & (df["consumption_comb(100km/l)"] > 12)
df.loc[condition, "consumption_comb(100km/l)"] = np.nan

# %% [markdown]
# ##### LPG/CNG

# %%
q3, q1 = np.percentile(df[df["fuel"] == "LPG/CNG"]["consumption_comb(100km/l)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (8.525, 0.32499999999999973)

# %%
condition = (df["fuel"]=="LPG/CNG") & (df["consumption_comb(100km/l)"] < lower_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
# Empty DataFrame
# Columns: [make_model, hp(kw), fuel, co2_emission(g/km), consumption_comb(100km/l)]
# Index: []

# %%
condition = (df["fuel"]=="LPG/CNG") & (df["consumption_comb(100km/l)"] > upper_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
# Empty DataFrame
# Columns: [make_model, hp(kw), fuel, co2_emission(g/km), consumption_comb(100km/l)]
# Index: []

# %% [markdown]
# ##### Electric

# %%
q3, q1 = np.percentile(df[df["fuel"] == "Electric"]["consumption_comb(100km/l)"], [75, 25])
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR
upper_bound, lower_bound
# Out:
# (1.6, 1.6)

# %%
condition = (df["fuel"]=="Electric") & (df["consumption_comb(100km/l)"] < lower_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
# Empty DataFrame
# Columns: [make_model, hp(kw), fuel, co2_emission(g/km), consumption_comb(100km/l)]
# Index: []

# %%
condition = (df["fuel"]=="Electric") & (df["consumption_comb(100km/l)"] > upper_bound)
df.loc[condition, ["make_model", "hp(kw)", "fuel", "co2_emission(g/km)", "consumption_comb(100km/l)"]].sort_values(by="co2_emission(g/km)").head(10)
# Out:
#          make_model  hp(kw)      fuel  co2_emission(g/km)  \
# 13397  Renault Clio    56.0  Electric                36.0
#
#        consumption_comb(100km/l)
# 13397                        3.3

# %%
df.loc[df.index==13397, "consumption_comb(100km/l)"] = np.nan

# %%
sns.boxplot(data=df, x="fuel", y="consumption_comb(100km/l)")
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='consumption_comb(100km/l)'>

# %% [markdown]
# ### Fill Null Values

# %%
df.isnull().sum()
# Out:
# make_model                    0
# body_type                     0
# price(€)                      0
# vat                           0
# km                            0
# hp(kw)                       55
# type                          0
# previous_owners               0
# inspection_new                0
# paint_type                    0
# num_of_door                   0
# num_of_seat                   0
# gearing_type                  0
# displacement(cc)             53
# cylinders                    12
# weight(kg)                    4
# drive_chain                   0
# fuel                          0
# co2_emission(g/km)           16
# emission_class                0
# comfort_and_convenience       0
# entertaintment_and_media      0
# extras                        0
# safety_and_security           0
# gears                        29
# age                           0
# upholstery_style              0
# upholstery_color              0
# consumption_comb(100km/l)    22
# dtype: int64

# %% [markdown]
# ##### 1- hp(kw)

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        condition = (df["make_model"] == makemodel) & (df["body_type"] == bodytype)
        median = df[condition]["hp(kw)"].median()    
        df.loc[condition, "hp(kw)"] = df.loc[condition, "hp(kw)"].fillna(median) 
df["hp(kw)"] = df["hp(kw)"].fillna(df["hp(kw)"].mode()[0])

# %%
df["hp(kw)"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### 2- displacement(cc)

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        for cylinder in df.loc[df["cylinders"].notnull(), "cylinders"].unique():
            for fueltype in df["fuel"].unique():
                condition =  (df["make_model"] == makemodel) & (df["fuel"]==fueltype) \
                & (df["body_type"] == bodytype) & (df.loc[df["cylinders"].notnull(), "cylinders"] == cylinder)
                median = df[condition]["displacement(cc)"].median()    
                df.loc[condition, "displacement(cc)"] = \
                df.loc[condition, "displacement(cc)"].fillna(median)

# %%
df["displacement(cc)"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### 3- cylinders

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
            for fueltype in df["fuel"].unique():
                condition =  (df["make_model"] == makemodel) & (df["fuel"]==fueltype) \
                & (df["body_type"] == bodytype)
                mode = df[condition]["cylinders"].mode()
                df.loc[condition, "cylinders"] = \
                df.loc[condition, "cylinders"].fillna(mode)

# %%
df["cylinders"].isnull().sum()

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
            for fueltype in df["fuel"].unique():
                condition =  (df["make_model"] == makemodel) & (df["fuel"]==fueltype) \
                & (df["body_type"] == bodytype)
                df.loc[condition, "cylinders"] = \
                df.loc[condition, "cylinders"].fillna(method="ffill").fillna(method="bfill")

# %%
df["cylinders"].isnull().sum()

# %% [markdown]
# ##### 4- weight(kg)

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        condition = (df["make_model"] == makemodel) & (df["body_type"] == bodytype)
        df.loc[condition, "weight(kg)"] = df.loc[condition, "weight(kg)"].fillna(method="ffill").fillna(method="bfill")

for bodytype in list(df["body_type"].unique()):
    condition = df["body_type"] == bodytype
    df.loc[condition, "weight(kg)"] = df.loc[condition, "weight(kg)"].fillna(method="ffill").fillna(method="bfill")

# %%
df["weight(kg)"].isnull().sum()

# %% [markdown]
# ##### 5- co2_emission(kg)

# %%
for fueltype in df["fuel"].unique():
    condition = df["fuel"] == fueltype
    median = df[condition]["co2_emission(g/km)"].median()    
    df.loc[condition, "co2_emission(g/km)"] = df.loc[condition, "co2_emission(g/km)"].fillna(median)

# %%
df["co2_emission(g/km)"].isnull().sum()

# %% [markdown]
# ##### 6- gears

# %%
for makemodel in df["make_model"].unique():
    for bodytype in df["body_type"].unique():
        condition = (df["body_type"] == bodytype) & (df["make_model"] == makemodel)
        df.loc[condition, "gears"] = df.loc[condition, "gears"].fillna(method="ffill").fillna(method="bfill")

for bodytype in df["body_type"].unique():
    condition = (df["body_type"] == bodytype)
    df.loc[condition, "gears"] = df.loc[condition, "gears"].fillna(method="ffill").fillna(method="bfill")

# %%
df["gears"].isnull().sum()

# %% [markdown]
# ##### 7- consumption_comb(100km/l)

# %%
for makemodel in df["make_model"].unique():
    for fueltype in df["fuel"].unique():
        for bodytype in df["body_type"].unique():
            condition =  (df["make_model"] == makemodel) & (df["fuel"]==fueltype) & (df["body_type"] == bodytype)
            median = df[condition]["consumption_comb(100km/l)"].median()    
            df.loc[condition, "consumption_comb(100km/l)"] = \
            df.loc[condition, "consumption_comb(100km/l)"].fillna(median)
                
for makemodel in df["make_model"].unique():
    for fueltype in df["fuel"].unique():
        condition =  (df["make_model"] == makemodel) & (df["fuel"]==fueltype)
        median = df[condition]["consumption_comb(100km/l)"].median()    
        df.loc[condition, "consumption_comb(100km/l)"] = \
        df.loc[condition, "consumption_comb(100km/l)"].fillna(median)
        
df["consumption_comb(100km/l)"] = df["consumption_comb(100km/l)"].fillna(method="ffill").fillna(method="bfill")

# %%
df["consumption_comb(100km/l)"].isnull().sum()

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ### Save To Csv Before Dummy Process

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# ### Get Dummies For Columns

# %%
df.info()

# %% [markdown]
# ##### comfort_and_convenience

# %%
com_and_con = df["comfort_and_convenience"].str.get_dummies(sep=",").add_prefix("CC_")

# %%
df = df.join(com_and_con)

# %% [markdown]
# ##### entertaintment_and_media

# %%
ent_and_med = df["entertaintment_and_media"].str.get_dummies(sep=",").add_prefix("EM_")

# %%
df = df.join(ent_and_med)

# %% [markdown]
# ##### extras

# %%
extras = df["extras"].str.get_dummies(sep=",").add_prefix("EX_")

# %%
df = df.join(extras)

# %% [markdown]
# ##### safety_and_security

# %%
safe_and_sec = df["safety_and_security"].str.get_dummies(sep=",").add_prefix("SS_")

# %%
df = df.join(safe_and_sec)

# %%
df.shape

# %% [markdown]
# #####  Drop Old Columns

# %%
df.drop(columns=["comfort_and_convenience", "entertaintment_and_media", "extras", "safety_and_security"], inplace=True)

# %% [markdown]
# ### Get Dummies For Dataframe

# %%
df.head()

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()

# %%
df.shape

# %% [markdown]
# ### Save To Csv After Dummy Process

# %%
pd.set_option('display.max_rows', 500)
df.isnull().sum()

# %%
df.to_csv("final_scout_dummy.csv", index=False)
